# %% [markdown]
# # Practica 3

# %% [markdown]
# Ejercicio 1:
#
# Crear una funcion constante42 que no reciba ningun parametro y siempre devuelva el numero 42
#
# *Ejemplo de input y output:*
#
# *Input: No tiene input*
#
# *Output: 42*

# %%
def constante42():
  #TODO: escribir aqui el codigo de su solucion
  return 42

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert constante42() == 42, "Error en el test 1"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 2:
#
# Crear una funcion crear_lista_vacia() que no reciba ningun parametro y siempre devuelva una lista vacia
#
# *Ejemplo de input y output:*
#
# *Input: No tiene input*
#
# *Output: []*

# %%
def crear_lista_vacia():
  #TODO: escribir aqui el codigo de su solucion
  return []

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert crear_lista_vacia() == [], "Error en el test 1"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 3:
#
# Crear una funcion crear_lista_de_n_a_m() que reciba dos parametros de tipo int y devuelva una lista con los numeros del n a m.
#
# Aclaraciones:
# - n y m siempre seran positivos
# - n siempre sera menor a m
#
# *Ejemplo de input y output:*
#
# *Input: n=3, m=9*
#
# *Output: [3,4,5,6,7,8,9]*

# %%
def crear_lista_de_n_a_m(n, m):
  #TODO: escribir aqui el codigo de su solucion
  return list(range(n,m+1))

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert crear_lista_de_n_a_m(3,9) == [3,4,5,6,7,8,9], "Error en el test 1"
assert crear_lista_de_n_a_m(0,2) == [0,1,2], "Error en el test 2"
assert crear_lista_de_n_a_m(10,14) == [10,11,12,13,14], "Error en el test 3"
assert crear_lista_de_n_a_m(100,105) == [100,101,102,103,104,105], "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 4:
#
# Crear una funcion crear_lista(n, v) que reciba dos parametros de tipo int y devuelva una lista de n elementos donde todos los elementos tengan el valor v
#
# Aclaraciones:
# - n siempre sera positivo
#
# *Ejemplo de input y output:*
#
# *Input: n=3, v=9*
#
# *Output: [9,9,9]*

# %%
def crear_lista(n, v):
  #TODO: escribir aqui el codigo de su solucion
  return [v] * n

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert crear_lista(3,9) == [9,9,9], "Error en el test 1"
assert crear_lista(1,2) == [2], "Error en el test 2"
assert crear_lista(5,100) == [100,100,100,100,100], "Error en el test 3"
assert crear_lista(3,"aprobado") == ["aprobado","aprobado","aprobado"], "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 5:
#
# Crear una funcion sumar(n, m) que reciba dos parametros de tipo int y devuelva la suma de los enteros de n a m
#
# Aclaraciones:
# - n y m siempre seran positivos
# - n siempre sera menor a m
#
# *Ejemplo de input y output:*
#
# *Input: n=2, n=5*
#
# *Output: 14*

# %%
def sumar(n, m):
  #TODO: escribir aqui el codigo de su solucion
  suma = 0
  for numero in range(n,m+1):
    suma += numero
  return suma

# %%
def sumar(n, m):
  #TODO: escribir aqui el codigo de su solucion
  return sum(range(n,m+1))

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert sumar(2,5) == 14, "Error en el test 1"
assert sumar(1,2) == 3, "Error en el test 2"
assert sumar(5,100) == 5040, "Error en el test 3"
assert sumar(1,1000) == 500500, "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 6:
#
# Crear una funcion largo_lista(x) que reciba un parametro de tipo lista y devuelva el largo de dicha lista
#
# *Ejemplo de input y output:*
#
# *Input: x=[4,6,3,2]*
#
# *Output: 4*

# %%
def largo_lista(x):
  #TODO: escribir aqui el codigo de su solucion
  return len(x)

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert largo_lista([4,6,3,2]) == 4, "Error en el test 1"
assert largo_lista([0]*500) == 500, "Error en el test 2"
assert largo_lista(list(range(100))) == 100, "Error en el test 3"
assert largo_lista(list(range(100000))) == 100000, "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 7:
#
# Crear una funcion largo(x) que reciba un parametro de tipo string y devuelva el largo de dicha string
#
# *Ejemplo de input y output:*
#
# *Input: x="Excelente"*
#
# *Output: 9*

# %%
def largo_string(x):
  #TODO: escribir aqui el codigo de su solucion
  return len(x)

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert largo_string("Excelente") == 9, "Error en el test 1"
assert largo_string("?"*500) == 500, "Error en el test 2"
assert largo_string("cool"*500) == 2000, "Error en el test 3"
assert largo_string("          ") == 10, "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 8:
#
# Crear una funcion elementoi_lista(x, p) que reciba un parametro de tipo lista y devuelva el valor del elemento que se encuentra en la posicion p (indice p-1)
#
# Aclaraciones:
#
# - x siempre sera una lista no vacia
# - p siempre sera un entero entre 1 y len(x)
#
# *Ejemplo de input y output:*
#
# *Input: x=[4,6,7,2], p=3*
#
# *Output: 7*

# %%
def elementoi_lista(x, p):
  #TODO: escribir aqui el codigo de su solucion
  return x[p-1]

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert elementoi_lista([4,6,7,2],3) == 7, "Error en el test 1"
assert elementoi_lista([0]*500,54) == 0, "Error en el test 2"
assert elementoi_lista(list(range(50,100)),11) == 60, "Error en el test 3"
assert elementoi_lista(list(range(100000)),100) == 99, "Error en el test 4"
assert elementoi_lista([4,6,7,2],4) == 2, "Error en el test 5"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 9:
#
# Crear una funcion elementoi_string(x, p) que reciba un parametro de tipo string y devuelva el valor del caracter que se encuentra en la posicion p (indice p-1)
#
# Aclaraciones:
#
# - x siempre sera un string no vacio
# - p siempre sera un entero entre 1 y len(x)
#
# *Ejemplo de input y output:*
#
# *Input: x="Excelente", p=4*
#
# *Output: 'e'*

# %%
def elementoi_string(x, p):
  #TODO: escribir aqui el codigo de su solucion
  return x[p-1]

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert elementoi_string("Excelente",4) == "e", "Error en el test 1"
assert elementoi_string("?"*500,154) == "?", "Error en el test 2"
assert elementoi_string("cool"*500,24) == "l", "Error en el test 3"
assert elementoi_string("awesome!",8) == "!", "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 10:
#
# Crear una funcion suma_valores_lista(x) que reciba un parametro de tipo lista y devuelva la suma de sus valores
#
# *Ejemplo de input y output:*
#
# *Input: x=[4,3,-1,3,0,2]*
#
# *Output: 11*

# %%
def suma_valores_lista(x):
  #TODO: escribir aqui el codigo de su solucion
  return sum(x)

# %%
def suma_valores_lista(x):
  #TODO: escribir aqui el codigo de su solucion
  ret = 0
  for n in x:
    ret += n
  return ret

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert suma_valores_lista([4,3,-1,3,0,2]) == 11, "Error en el test 1"
assert suma_valores_lista([0,0,0,0,1]) == 1, "Error en el test 2"
assert suma_valores_lista([-1,0,0,0,1]) == 0, "Error en el test 3"
assert suma_valores_lista([1,2,3,4,5]) == 15, "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 11:
#
# Crear una funcion sumar_listas(x, y) que reciba dos parametros de tipo lista y devuelva una nueva lista con la suma de los valores que se encuentran en la misma posicion, es decir, lista_nueva[i] = x[i] + y[i]
#
# Aclaraciones:
#
# - x e y siempre tendran la misma cantidad de elementos
#
# *Ejemplo de input y output:*
#
# *Input: x=[2,1,3,5], y=[4,0,1,0]*
#
# *Output: [6,1,4,5]*

# %%
def sumar_listas(x,y):
  #TODO: escribir aqui el codigo de su solucion
  z = [0]*len(x)
  for i in range(len(x)):
    z[i] = x[i] + y[i]
  return z

# %%
def sumar_listas(x,y):
  #TODO: escribir aqui el codigo de su solucion
  z = []
  for i in range(len(x)):
    z.append(x[i] + y[i])
  return z

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert sumar_listas([2,1,3,5], [4,0,1,0]) == [6,1,4,5], "Error en el test 1"
assert sumar_listas([2], [3]) == [5], "Error en el test 2"
assert sumar_listas([],[]) == [], "Error en el test 3"
assert sumar_listas([1,2,3],[9,8,7]) == [10,10,10], "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 12:
#
# Crear una funcion lista_suma_mayor(x, y) que reciba dos parametros de tipo lista y devuelva la lista cuya suma de sus valores sea mayor
#
# *Ejemplo de input y output:*
#
# *Input: x=[2,1,3,5], y=[4,0,1,0]
#
# *Output: [2,1,3,5]*
#
# *Explicacion: la suma de los valores de x es 2+1+3+5=11 y la suma de los valores de y es 4+0+1+0=5 por lo tanto devuelvo la lista x porque la suma de sus valores es 11 que es mayor a la suma de los valores de la suma de la lista y que es 5

# %%
def lista_suma_mayor(x,y):
  #TODO: escribir aqui el codigo de su solucion
  sumax = sum(x)
  sumay = sum(y)
  if sumax > sumay:
    return x
  else:
    return y

# %%
def lista_suma_mayor(x,y):
  #TODO: escribir aqui el codigo de su solucion
  sumax = suma_valores_lista(x)
  sumay = suma_valores_lista(y)
  if sumax > sumay:
    return x
  else:
    return y

# %%
def lista_suma_mayor(x,y):
  #TODO: escribir aqui el codigo de su solucion
  sumax = 0
  for n in x:
    sumax += n
  sumay = 0
  for n in y:
    sumay += n
  if sumax > sumay:
    return x
  else:
    return y

# %%
def lista_suma_mayor(x,y):
  #TODO: escribir aqui el codigo de su solucion
  sumax = 0
  for n in x:
    sumax += n
  print("Suma de los valores de x:",sumax)
  sumay = 0
  for n in y:
    sumay += n
  print("Suma de los valores de y:",sumay)
  if sumax > sumay:
    return x
  else:
    return y

# %%
a = lista_suma_mayor([2,1,3,5], [4,0,1,0])
print("Mi funcion devuelve:", a)
print("Deberia devolver:   ", [2,1,3,5])
# Out:
# Suma de los valores de x: 11
# Suma de los valores de y: 5
# Mi funcion devuelve: [2, 1, 3, 5]
# Deberia devolver:    [2, 1, 3, 5]

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert lista_suma_mayor([2,1,3,5], [4,0,1,0]) == [2,1,3,5], "Error en el test 1"
assert lista_suma_mayor([2], [3,6]) == [3,6], "Error en el test 2"
assert lista_suma_mayor([],[]) == [], "Error en el test 3"
assert lista_suma_mayor([1,2,3],[9,8,7]) == [9,8,7], "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Suma de los valores de x: 11
# Suma de los valores de y: 5
# Suma de los valores de x: 2
# Suma de los valores de y: 9
# Suma de los valores de x: 0
# Suma de los valores de y: 0
# Suma de los valores de x: 6
# Suma de los valores de y: 24
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 13:
#
# Crear una funcion sumar_listas2(x, y) que reciba dos parametros de tipo lista y devuelva una nueva lista con la suma de los valores de la primera mas los de la segunda invertida, es decir, lista_nueva[i] = x[i] + y[n-1-i] donde n = len(x)
#
# Aclaraciones:
#
# - x e y siempre tendran la misma cantidad de elementos
#
# *Ejemplo de input y output:*
#
# *Input: x=[2,1,3,5], y=[4,0,1,0]*
#
# *Output: [2,2,3,9]*

# %%
def sumar_listas2(x,y):
  #TODO: escribir aqui el codigo de su solucion
  n = len(x)
  z = [0]*len(x)
  for i in range(len(x)):
    z[i] = x[i] + y[n-1-i]
  return z

# %%
def sumar_listas2(x,y):
  return sumar_listas(x,y[::-1])

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert sumar_listas2([2,1,3,5], [4,0,1,0]) == [2,2,3,9], "Error en el test 1"
assert sumar_listas2([2], [3]) == [5], "Error en el test 2"
assert sumar_listas2([],[]) == [], "Error en el test 3"
assert sumar_listas2([1,2,3],[9,8,7]) == [8,10,12], "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!

# %% [markdown]
# Ejercicio 14:
#
# Crear una funcion suma_de_aleatorios(semilla) que reciba un parametro de tipo int y genere numero aleatorios utilizando la funcion random.randrange(0,100) hasta que se genere el numero cero. Devolver la suma de todos los numeros generados.
#
# *Ejemplo de input y output:*
#
# *Input: semilla=1*
#
# *Output: 1128*

# %%
import random
def suma_de_aleatorios(semilla):
  random.seed(semilla)
  #TODO: escribir aqui el codigo de su solucion
  n = random.randrange(0,100)
  suma = n
  while n != 0:
    n = random.randrange(0,100)
    suma += n
  return suma

# %%
#NO MODIFICAR EL SIGUIENTE CODIGO
#Codigo de test para verificar si la funcion es correcta
assert suma_de_aleatorios(1) == 1128, "Error en el test 1"
assert suma_de_aleatorios(2) == 8319, "Error en el test 2"
assert suma_de_aleatorios(3) == 6683, "Error en el test 3"
assert suma_de_aleatorios(42) == 1693, "Error en el test 4"
print("Felicitaciones! Todos los tests fueron pasados exitosamente!")
# Out:
# Felicitaciones! Todos los tests fueron pasados exitosamente!
