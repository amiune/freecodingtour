# %% [markdown]
# # Web scrapping de Supermercados Dia
#
# Guardar la informacion (descripcion, precio y formato) de las cervezas nacionales en un dataframe de pandas

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
URL = "https://www.dia.es/compra-online/bebidas/cervezas/nacionales/cf"

# %%
URL = "https://www.compraonline.alcampo.es/categories/bebidas/cervezas/cerveza-lata-est%C3%A1ndar/OC110701"

# %%
response = requests.get(URL)
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n    <html lang="es">\n      <head>\n        <link rel="stylesheet" type="text/css" href="/plp-front/assets/1-28-0/style.css">\n        <link rel="preload" href="/plp-front/assets/1-28-0/diaIcomoon.ttf" as="font" type="font/ttf" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/diaIcomoon.woff" as="font" type="font/woff" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/roboto-medium-webfont.woff2" as="font" type="font/woff2" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/roboto-medium-webfont.woff" as="font" type="font/woff" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/Roboto-Medium.ttf" as="font" type="font/ttf" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/roboto-bold-webfont.woff2" as="font" type="font/woff2" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/roboto-bold-webfont.woff" as="font" type="font/woff" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/Roboto-Bold.ttf" as="font" type="font/ttf" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/Roboto-Black.ttf" as="font" type="font/ttf" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/roboto-regular-webfont.woff2" as="font" type="font/woff2" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/roboto-regular-webfont.woff" as="font" type="font/woff" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/Roboto-Regular.ttf" as="font" type="font/ttf" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/montserrat-medium.ttf" as="font" type="font/ttf" crossorigin>\n        <link rel="preload" href="/plp-front/assets/1-28-0/montserrat-semibold.ttf" as="font" type="font/ttf" crossorigin>\n        <meta charset="UTF-8" />\n        <!-- El aviso de consentimiento de cookies de OneTrust comienza para dev.dia.es. -->\n        \n        <script defer src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="5a716931-44b0-415f-9bf7-3a94d961c123"></script>\n        <script defer type="text/javascript">\n        function OptanonWrapper() { }\n        </script>\n        <meta name="robots" content="index, follow" />\n        <link rel="canonical" href="https://www.dia.es/cervezas-vinos-y-bebidas-con-alcohol/cervezas/c/L2115">\n        <link rel="alternate" href="https://www.dia.es/cervezas-vinos-y-bebidas-con-alcohol/cervezas/c/L2115" hreflang="es-es" >\n        <link rel="stylesheet" type="text/css" href="/plp-front/assets/1-28-0/style.css">\n        <link rel="icon" href="/plp-front/assets/images/logo-dia.svg" as="icon"/>\n        <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n        <meta name="keywords" content="">\n        <meta name="description" content="Compra online en la sección de Cervezas y disfruta de todas nuestras ofertas en dia.es" />\n        <title>Comprar Cervezas - Supermercados DIA</title>\n      \n<script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>\n                              <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="KBNBM-CLU64-6QM35-AYNSF-TJWYH",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d= ...

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.title
# Out:
# <title>Comprar Cervezas - Supermercados DIA</title>

# %%
# Out:
#                                              Articulo          Precio  \
# 0       DIA RAMBLERS cerveza lager lata 33 cl PACK 12          3,96 €
# 1                MAHOU 5 ESTRELLAS cerveza lata 50 cl          1,09 €
# 2                    MAHOU cerveza clásica lata 50 cl          0,98 €
# 3            SAN MIGUEL cerveza pack 6 botellas 25 cl          3,49 €
# 4                  MAHOU cerveza clásica botella 1 lt          1,71 €
# 5           MAHOU cerveza clásica pack 12 latas 33 cl          8,28 €
# 6    DIA RAMBLERS cerveza lager pack 6 botellas 25 cl  2,10 €\n1,68 €
# 7                MAHOU 5 ESTRELLAS cerveza lata 33 cl  0,81 €\n0,65 €
# 8                AMSTEL cerveza pack 6 botellas 25 cl          3,29 €
# 9               DIA RAMBLERS cerveza lager lata 33 cl          0,33 €
# 10             SAN MIGUEL cerveza pack 12 latas 33 cl          7,99 €
# 11                      SAN MIGUEL cerveza lata 33 cl          0,69 €
# 12        MAHOU cerveza clásica pack 6 botellas 25 cl          3,49 €
# 13                   MAHOU cerveza clásica lata 33 cl          0,69 €
# 14              DIA RAMBLERS cerveza lager lata 50 cl  0,50 €\n0,42 €
# 15                 LA VIRGEN cerveza lager lata 33 cl          1,58 €
# 16  ESTRELLA DAMM cerveza rubia nacional pack 12 b...          7,95 €
# 17  MAHOU 5 ESTRELLAS cerveza pack 6 botellas x 25 cl          4,15 €
# 18                        SUREÑA cerveza botella 1 lt          1,29 €
# 19                  AMSTEL cerveza clásica lata 33 cl          0,45 €
# 20          MAHOU cerveza clásica pack 24 latas 33 cl         15,99 €
# 21                EL AGUILA cerveza dorada lata 33 cl  0,85 €\n0,69 €
# 22   DIA RAMBLERS cerveza lager botella plástico 1 lt          0,95 €
# 23    ALHAMBRA cerveza especial pack 6 botellas 20 cl          3,49 €
#
#                  Formato
# 0              1,00 €/l.
# 1              2,18 €/l.
# 2              1,96 €/l.
# 3              2,33 €/l.
# 4              1,71 €/l.
# 5              2,09 €/l.
# 6   1,40 €/l.\n1,12 €/l.
# 7   2,45 €/l.\n1,97 €/l.
# 8              2,19 €/l.
# 9              1,00 €/l.
# 10             2,02 €/l.
# 11             2,09 €/l.
# 12             2,33 €/l.
# 13             2,09 €/l.
# 14  1,00 €/l.\n0,84 €/l.
# 15             4,79 €/l.
# 16             2,65 €/l.
# 17             2,77 €/l.
# 18             1,29 €/l.
# 19             1,36 €/l.
# 20             2,02 €/l.
# 21  2,58 €/l.\n2,09 €/l.
# 22             0,95 €/l.
# 23             2,91 €/l.
