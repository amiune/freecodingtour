# %% [markdown]
# # Ensemble

# %%
import numpy as np
import pandas as pd

# %%
df_xlnet = pd.read_csv('./xlnet_large_probs.csv', index_col="id")
df_roberta = pd.read_csv('./roberta_large_probs.csv', index_col="id")
df_multinomialnb = pd.read_csv('./multinomialnb_probs.csv', index_col="id")

# %%
df_xlnet.head(3)
# Out:
#          action  adventure     crime    family   fantasy    horror   mystery  \
# id
# 16863  0.726205   0.842741  0.790542  0.951253  0.365330  0.210975  0.391840
# 48456  0.272133   0.217783  0.241611  0.031787  0.714874  0.984259  0.898373
# 41383  0.623400   0.772242  0.049801  0.813639  0.967562  0.337011  0.398359
#
#         romance     scifi  thriller
# id
# 16863  0.235947  0.081614  0.480308
# 48456  0.126108  0.399847  0.917401
# 41383  0.506324  0.566431  0.154448

# %%
(df_xlnet**2).head(3)
# Out:
#          action  adventure     crime    family   fantasy    horror   mystery  \
# id
# 16863  0.527374   0.710212  0.624957  0.904883  0.133466  0.044511  0.153538
# 48456  0.074056   0.047429  0.058376  0.001010  0.511045  0.968766  0.807075
# 41383  0.388627   0.596357  0.002480  0.662009  0.936177  0.113577  0.158690
#
#         romance     scifi  thriller
# id
# 16863  0.055671  0.006661  0.230696
# 48456  0.015903  0.159877  0.841624
# 41383  0.256364  0.320844  0.023854

# %%
df_roberta.head(3)
# Out:
#          action  adventure     crime    family   fantasy    horror   mystery  \
# id
# 16863  0.787994   0.826750  0.805616  0.899376  0.271692  0.095042  0.269157
# 48456  0.237595   0.314073  0.291333  0.060383  0.549227  0.970637  0.832730
# 41383  0.553515   0.719178  0.085570  0.581612  0.935160  0.438431  0.468459
#
#         romance     scifi  thriller
# id
# 16863  0.408133  0.069500  0.439665
# 48456  0.129948  0.343269  0.859453
# 41383  0.288177  0.556214  0.330233

# %%
df_multinomialnb.head(3)
# Out:
#          action  adventure     crime    family   fantasy    horror   mystery  \
# id
# 16863  0.126043   0.097572  0.160630  0.138484  0.076402  0.073603  0.075325
# 48456  0.076269   0.087137  0.083783  0.067785  0.086920  0.231009  0.094130
# 41383  0.069682   0.085261  0.066910  0.157717  0.116080  0.097841  0.099183
#
#         romance     scifi  thriller
# id
# 16863  0.081371  0.075496  0.095074
# 48456  0.076005  0.073193  0.123769
# 41383  0.118119  0.108144  0.081063

# %%
df_ensemble = (df_xlnet + df_roberta) / 2
df_ensemble.head(2)
# Out:
#          action  adventure     crime    family   fantasy    horror   mystery  \
# id
# 16863  0.757099   0.834746  0.798079  0.925315  0.318511  0.153008  0.330498
# 48456  0.254864   0.265928  0.266472  0.046085  0.632051  0.977448  0.865552
#
#         romance     scifi  thriller
# id
# 16863  0.322040  0.075557  0.459987
# 48456  0.128028  0.371558  0.888427

# %%
preds = []
for row in range(len(df_xlnet)):
    preds.append(df_xlnet.columns[np.argmax(df_ensemble.iloc[row,:])])

# %%
preds[0:3]
# Out:
# ['family', 'horror', 'fantasy']

# %%
df_probs = pd.DataFrame({"id":df_xlnet.index,"genre":preds})
df_probs.to_csv("ensemble_submission.csv", index=False)

# %%
# score: 0.43044444444444446
