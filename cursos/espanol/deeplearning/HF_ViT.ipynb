# %%
#!pip install transformers --quiet
#!pip install torch --quiet
#!pip install tensorflow --quiet

# %%
from transformers import pipeline

# %%
#https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/
classifier = pipeline("image-classification")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 5dca96d (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
url = 'https://t1.ea.ltmcdn.com/es/posts/5/6/2/10_caracteristicas_de_los_perros_24265_600_square.jpg'
classifier(images=url, top_k=1)
# Out:
# [{'score': 0.48814740777015686, 'label': 'beagle'}]

# %%
url = "https://i.blogs.es/742e4d/como-obtener-al-pikachu-de-ash-en-pokemon-sword-shield-para-nintendo-switch-en-mexico-y-latam-1/840_560.jpeg"
classifier(images=url, top_k=1)
# Out:
# [{'score': 0.8308597803115845, 'label': 'comic book'}]

# %%
classifier = pipeline("image-classification", model="amiune/autotrain-pokemonclassification-42305108508")

# %%
url = "https://i.blogs.es/742e4d/como-obtener-al-pikachu-de-ash-en-pokemon-sword-shield-para-nintendo-switch-en-mexico-y-latam-1/840_560.jpeg"
classifier(images=url, top_k=1)
# Out:
# [{'score': 0.9972200393676758, 'label': 'pikachu'}]
