# %% [markdown]
# # TODO:
#
# - [What Is Shor's Algorithm - And Why It's the Single Biggest Threat to Classical Cryptography](https://blog.ellipticc.com/posts/what-is-shors-algorithm-and-why-its-the-single-biggest-threat-to-classical-cryptography/)
# - [Thomas Wong](https://www.thomaswong.net)
# - [Michael Nielsen Quantum Country](https://quantum.country)
