# %% [markdown]
# # Q Learning
#
# In this unit we will create an agent that learns by playing by using the qlearning algorithm to generate a table (the Q table) that stores a value for each state-action pair

# %%
import copy
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.animation import FuncAnimation
from matplotlib import rc

# Ensure animations can be displayed inline
rc('animation', html='jshtml')

class MazeGame:
    def __init__(self):
        self.board = [
            ['😊', '😺', ' '],
            [' ', ' ', ' '],
            ['😺', ' ', '😍']
        ]
        self.board_values = [
            [-1,  20, -1],
            [-1, -1, -1],
            [ 20, -1, 100]
        ]
        self.player_pos = (0, 0)  # Starting position
        self.goal_pos = (2, 2)  # Goal position
        self.board_history = []  # To store the board state at each step
        self.board_history.append(copy.deepcopy(self.board))  # Store initial state

    def render_animation(self):
        """
        Creates an animation that shows the progression of the game
        """
        fig, ax = plt.subplots()
        ax.set_xticks(np.arange(0, 3 + 1, 1))
        ax.set_yticks(np.arange(0, 3 + 1, 1))
        ax.grid(True, color='black')

        # Set limits and reverse y-axis to have (0,0) in top-left
        ax.set_xlim(0, 3)
        ax.set_ylim(0, 3)
        ax.invert_yaxis()

        # Initialize a list of text objects for each cell
        text_objects = []
        for i in range(3):
            row = []
            for j in range(3):
                text = ax.text(j + 0.5, i + 0.5, '', ha='center', va='center', fontsize=50)
                row.append(text)
            text_objects.append(row)

        # Function to update the board for each frame of the animation
        def update(frame):
            board = self.board_history[frame]
            for i in range(3):
                for j in range(3):
                    text_objects[i][j].set_text(board[i][j])
            return [item for sublist in text_objects for item in sublist]

        # Create the animation
        ani = FuncAnimation(fig, update, frames=len(self.board_history), interval=500, blit=True)
        plt.close(fig)
        return ani

    def move(self, direction):
        """
        Moves the player one cell in the specified direction.

        Args:
          direction: A string indicating the direction to move ('up', 'down', 'left', 'right').
        """
        x, y = self.player_pos
        if direction == 'up' and x > 0:
            self.board[x][y] = ' '
            x -= 1
        elif direction == 'down' and x < 2:
            self.board[x][y] = ' '
            x += 1
        elif direction == 'left' and y > 0:
            self.board[x][y] = ' '
            y -= 1
        elif direction == 'right' and y < 2:
            self.board[x][y] = ' '
            y += 1
        else:
            #print("Invalid move!")
            return

        # Update the board with the new player position
        self.board[x][y] = '😊'
        self.player_pos = (x, y)

        # Check if player reached the goal
        if self.player_pos == self.goal_pos:
            self.board[x][y] = '😊😍'
            #print(f"You reached the goal in {len(self.board_history)} moves!")

        # Append the updated board state to the history
        self.board_history.append(copy.deepcopy(self.board))

# %%
import random
from collections import defaultdict

class QLearningAgent:
    def __init__(self, maze_game, learning_rate=0.01, discount_factor=1.0, exploration_rate=1.0, exploration_decay=0.99):
        self.maze_game = maze_game
        self.q_table = defaultdict(lambda: np.zeros(4))  # Initialize Q-table for each state, with 4 actions (up, down, left, right)
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_rate = exploration_rate
        self.exploration_decay = exploration_decay
        self.actions = ['up', 'down', 'left', 'right']  # Possible actions
        self.visited = set()  # Keep track of visited states in each episode

    def get_state(self):
        # The state can be represented by the player's position on the board
        return self.maze_game.player_pos

    def is_valid_move(self, state, action):
        """
        Check if the move is valid (doesn't move out of bounds or into a wall).
        """
        x, y = state
        if action == 'up':
            new_x, new_y = x - 1, y
        elif action == 'down':
            new_x, new_y = x + 1, y
        elif action == 'left':
            new_x, new_y = x, y - 1
        elif action == 'right':
            new_x, new_y = x, y + 1

        # Check if the new position is out of bounds
        if new_x < 0 or new_x >= 3 or new_y < 0 or new_y >= 3:
            return False

        # Check if the new position has already been visited
        if (new_x, new_y) in self.visited:
            return False

        return True

    def choose_action(self, state, explore=True):
        """
        Choose a valid action using ε-greedy strategy, and avoid invalid or revisited moves.
        """
        valid_actions = [action for action in self.actions if self.is_valid_move(state, action)]

        if explore and np.random.rand() < self.exploration_rate:
            # Choose a random valid action
            if valid_actions:
                return random.choice(valid_actions)
            else:
                return None  # If no valid action is available
        else:
            # Choose the best action according to Q-table, only from valid actions
            q_values = self.q_table[state]
            if valid_actions:
                best_valid_action = max(valid_actions, key=lambda action: q_values[self.actions.index(action)])
                return best_valid_action
            else:
                return None  # If no valid action is available

    def learn(self, state, action, reward, next_state):
        """
        Q-learning update rule.
        """
        action_index = self.actions.index(action)
        best_future_q = np.max(self.q_table[next_state])
        current_q = self.q_table[state][action_index]

        # Update the Q-value for the current state-action pair
        new_q = (1 - self.learning_rate) * current_q + self.learning_rate * (reward + self.discount_factor * best_future_q)
        self.q_table[state][action_index] = new_q

    def update_exploration_rate(self):
        # Reduce exploration rate after each episode
        self.exploration_rate *= self.exploration_decay

    def play(self, episodes=1000):
        for episode in range(episodes):
            self.maze_game.__init__()  # Reset the game for each episode
            self.visited = set()  # Reset visited cells at the beginning of each episode
            state = self.get_state()
            self.visited.add(state)  # Mark the starting position as visited
            total_reward = 0
            step = 0

            while state != self.maze_game.goal_pos:
                action = self.choose_action(state)
                if action is None:
                    print("No valid moves left! Stuck.")
                    break

                prev_state = state

                # Execute action in the environment
                self.maze_game.move(action)
                state = self.get_state()

                # Add the new state to the visited set
                self.visited.add(state)

                # Calculate reward based on the board values
                x, y = state
                reward = self.maze_game.board_values[x][y]

                # Update Q-table based on the action taken
                self.learn(prev_state, action, reward, state)
                total_reward += reward
                step += 1

                if state == self.maze_game.goal_pos:
                    print(f"Episode {episode + 1}: Reached goal in {step} steps with total reward {total_reward}")
                    break

            # Decay the exploration rate
            self.update_exploration_rate()

    def play_one_episode(self):
        """
        Play one episode using the learned Q-table, without exploration, and avoid revisiting cells.
        """
        self.maze_game.__init__()  # Reset the game to initial state
        self.visited = set()  # Reset visited cells
        state = self.get_state()
        self.visited.add(state)  # Mark the starting position as visited
        step = 0
        total_reward = 0

        while state != self.maze_game.goal_pos:
            # Always exploit the best action from the Q-table, and ensure it's valid and not revisited
            action = self.choose_action(state, explore=False)
            if action is None:
                print("No valid moves left! Stuck.")
                break

            print(f"Step {step + 1}: Moving {action} from {state}")

            # Execute the action in the environment
            self.maze_game.move(action)
            state = self.get_state()

            # Add the new state to the visited set
            self.visited.add(state)

            # Calculate reward based on the board values
            x, y = state
            reward = self.maze_game.board_values[x][y]
            total_reward += reward

            step += 1

            # Check if reached the goal
            if state == self.maze_game.goal_pos:
                print(f"Reached the goal in {step} steps with total reward: {total_reward}")
                break

# %%
# Create the maze game
maze_game = MazeGame()

# Create the Q-learning agent
agent = QLearningAgent(maze_game, learning_rate=0.1, discount_factor=0.0, exploration_rate=1.0, exploration_decay=0.0)

# Train the agent (you can adjust the number of episodes)
agent.play(episodes=1000)
# Out:
# Episode 1: Reached goal in 4 steps with total reward 118
# No valid moves left! Stuck.
# Episode 3: Reached goal in 6 steps with total reward 137
# Episode 4: Reached goal in 4 steps with total reward 118
# Episode 5: Reached goal in 4 steps with total reward 118
# Episode 6: Reached goal in 4 steps with total reward 118
# Episode 7: Reached goal in 4 steps with total reward 118
# Episode 8: Reached goal in 4 steps with total reward 118
# Episode 9: Reached goal in 6 steps with total reward 137
# Episode 10: Reached goal in 4 steps with total reward 118
# Episode 11: Reached goal in 4 steps with total reward 118
# Episode 12: Reached goal in 4 steps with total reward 118
# Episode 13: Reached goal in 4 steps with total reward 118
# Episode 14: Reached goal in 4 steps with total reward 118
# Episode 15: Reached goal in 6 steps with total reward 137
# Episode 16: Reached goal in 4 steps with total reward 118
# Episode 17: Reached goal in 4 steps with total reward 118
# Episode 18: Reached goal in 4 steps with total reward 118
# Episode 19: Reached goal in 4 steps with total reward 118
# Episode 20: Reached goal in 4 steps with total reward 118
# Episode 21: Reached goal in 6 steps with total reward 137
# Episode 22: Reached goal in 4 steps with total reward 118
# Episode 23: Reached goal in 4 steps with total reward 118
# Episode 24: Reached goal in 4 steps with total reward 118
# Episode 25: Reached goal in 4 steps with total reward 118
# Episode 26: Reached goal in 4 steps with total reward 118
# Episode 27: Reached goal in 6 steps with total reward 137
# Episode 28: Reached goal in 4 steps with total reward 118
# Episode 29: Reached goal in 4 steps with total reward 118
# Episode 30: Reached goal in 4 steps with total reward 118
# Episode 31: Reached goal in 4 steps with total reward 118
# Episode 32: Reached goal in 4 steps with total reward 118
# Episode 33: Reached goal in 6 steps with total reward 137
# Episode 34: Reached goal in 4 steps with total reward 118
# Episode 35: Reached goal in 4 steps with total reward 118
# Episode 36: Reached goal in 4 steps with total reward 118
# Episode 37: Reached goal in 4 steps with total reward 118
# Episode 38: Reached goal in 4 steps with total reward 118
# Episode 39: Reached goal in 6 steps with total reward 137
# Episode 40: Reached goal in 4 steps with total reward 118
# Episode 41: Reached goal in 4 steps with total reward 118
# Episode 42: Reached goal in 4 steps with total reward 118
# Episode 43: Reached goal in 4 steps with total reward 118
# Episode 44: Reached goal in 4 steps with total reward 118
# Episode 45: Reached goal in 6 steps with total reward 137
# Episode 46: Reached goal in 4 steps with total reward 118
# Episode 47: Reached goal in 4 steps with total reward 118
# Episode 48: Reached goal in 4 steps with total reward 118
# Episode 49: Reached goal in 4 steps with total reward 118
# Episode 50: Reached goal in 4 steps with total reward 118
# Episode 51: Reached goal in 6 steps with total reward 137
# Episode 52: Reached goal in 4 steps with total reward 118
# Episode 53: Reached goal in 4 steps with total reward 118
# Episode 54: Reached goal in 4 steps with total reward 118
# Episode 55: Reached goal in 4 steps with total reward 118
# Episode 56: Reached goal in 4 steps with total reward 118
# Episode 57: Reached goal in 6 steps with total reward 137
# Episode 58: Reached goal in 4 steps with total reward 118
# Episode 59: Reached goal in 4 steps with total reward 118
# Episode 60: Reached goal in 4 steps with total reward 118
# Episode 61: Reached goal in 4 steps with total reward 118
# Episode 62: Reached goal in 4 steps with total reward 118
# Episode 63: Reached goal in 6 steps with total reward 137
# Episode 64: Reached goal in 4 steps with total reward 118
# Episode 65: Reached goal in 4 steps with total reward 118
# Episode 66: Reached goal in 4 steps with total reward 118
# Episode 67: Reached goal in 4 steps with total reward 118
# Episode 68: Reached goal in 4 steps with total reward 118
# Episode 69: Reached goal in 6 steps with total reward 137
# Episode 70: Reached goal in 4 steps with total reward 118
# Episode 71: Reached goal in 4 steps with total reward 118
# Episode 72: Reached goal in 4 steps with total reward 118
# Episode 73: Reached goal in 4 steps with total reward 118
# Episode 74: Reached goal in 4 steps with total reward 118
# Episode 75: Reached goal in 6 steps with total reward 137
# Episode 76: Reached goal in 4 steps with total reward 118
# Episode 77: Reached goal in 4 steps with total reward 118
# Episode 78: Reached goal in 4 steps with total reward 118
# Episode 79: Reached goal in 4 steps with total reward 118
# Episode 80: Reached goal in 4 steps with total reward 118
# Episode 81: Reached goal in 6 steps with total reward 137
# Episode 82: Reached goal in 4 steps with total reward 118
# Episode 83: Reached goal in 4 steps with total reward 118
# Episode 84: Reached goal in 4 steps with total reward 118
# Episode 85: Reached goal in 4 steps with total reward 118
# Episode 86: Reached goal in 4 steps with total reward 118
# Episode 87: Reached goal in 6 steps with total reward 137
# Episode 88: Reached goal in 4 steps with total reward 118
# Episode 89: Reached goal in 4 steps with total reward 118
# Episode 90: Reached goal in 4 steps with total reward 118
# Episode 91: Reached goal in 4 steps with total reward 118
# Episode 92: Reached goal in 4 steps with total reward 118
# Episode 93: Reached goal in 6 steps with total reward 137
# Episode 94: Reached goal in 4 steps with total reward 118
# Episode 95: Reached goal in 4 steps with total reward 118
# Episode 96: Reached goal in 4 steps with total reward 118
# Episode 97: Reached goal in 4 steps with total reward 118
# Episode 98: Reached goal in 4 steps with total reward 118
# Episode 99: Reached goal in 6 steps with total reward 137
# Episode 100: Reached goal in 4 steps with total reward 118
# Episode 101: Reached goal in 4 steps with total reward 118
# Episode 102: Reached goal in 4 steps with total reward 118
# Episode 103: Reached goal in 4 steps with total reward 118
# Episode 104: Reached goal in 4 steps with total reward 118
# Episode 105: Reached goal in 6 steps with total reward 137
# Episode 106: Reached goal in 4 steps with total reward 118
# Episode 107: Reached goal in 4 steps with total reward 118
# Episode 108: Reached goal in 4 steps with total reward 118
# Episode 109: Reached goal in 4 steps with total reward 118
# Episode 110: Reached goal in 4 steps with total reward 118
# Episode 111: Reached goal in 6 steps with total reward 137
# Episode 112: Reached goal in 4 steps with total reward 118
# Episode 113: Reached goal in 4 steps with total reward 118
# Episode 114: Reached goal in 4 steps with total reward 118
# Episode 115: Reached goal in 4 steps with total reward 118
# Episode 116: Reached goal in 4 steps with total reward 118
# Episode 117: Reached goal in 6 steps with total reward 137
# Episode 118: Reached goal in 4 steps with total reward 118
# Episode 119: Reached goal in 4 steps with total reward 118
# Episode 120: Reached goal in 4 steps with total reward 118
# Episode 121: Reached goal in 4 steps with total reward 118
# Episode 122: Reached goal in 4 steps with total reward 118
# Episode 123: Reached goal in 6 steps with total reward 137
# Episode 124: Reached goal in 4 steps with total reward 118
# Episode 125: Reached goal in 4 steps with total reward 118
# Episode 126: Reached goal in 4 steps with total reward 118
# Episode 127: Reached goal in 4 steps with total reward 118
# Episode 128: Reached goal in 4 steps with total reward 118
# Episode 129: Reached goal in 6 steps with total reward 137
# Episode 130: Reached goal in 4 steps with total reward 118
# Episode 131: Reached goal in 4 steps with total reward 118
# Episode 132: Reached goal in 4 steps with total reward 118
# Episode 133: Reached goal in 4 steps with total reward 118
# Episode 134: Reached goal in 4 steps with total reward 118
# Episode 135: Reached goal in 6 steps with total reward 137
# Episode 136: Reached goal in 4 steps with total reward 118
# Episode 137: Reached goal in 4 steps with total reward 118
# Episode 138: Reached goal in 4 steps with total reward 118
# Episode 139: Reached goal in 4 steps with total reward 118
# Episode 140: Reached goal in 4 steps with total reward 118
# Episode 141: Reached goal in 6 steps with total reward 137
# Episode 142: Reached goal in 4 steps with total reward 118
# Episode 143: Reached goal in 4 steps with total reward 118
# Episode 144: Reached goal in 4 steps with total reward 118
# Episode 145: Reached goal in 4 steps with total reward 118
# Episode 146: Reached goal in 4 steps with total reward 118
# Episode 147: Reached goal in 6 steps with total reward 137
# Episode 148: Reached goal in 4 steps with total reward 118
# Episode 149: Reached goal in 4 steps with total reward 118
# Episode 150: Reached goal in 4 steps with total reward 118
# Episode 151: Reached goal in 4 steps with total reward 118
# Episode 152: Reached goal in 4 steps with total reward 118
# Episode 153: Reached goal in 6 steps with total reward 137
# Episode 154: Reached goal in 4 steps with total reward 118
# Episode 155: Reached goal in 4 steps with total reward 118
# Episode 156: Reached goal in 4 steps with total reward 118
# Episode 157: Reached goal in 4 steps with total reward 118
# Episode 158: Reached goal in 4 steps with total reward 118
# Episode 159: Reached goal in 6 steps with total reward 137
# Episode 160: Reached goal in 4 steps with total reward 118
# Episode 161: Reached goal in 4 steps with total reward 118
# Episode 162: Reached goal in 4 steps with total reward 118
# Episode 163: Reached goal in 4 steps with total reward 118
# Episode 164: Reached goal in 4 steps with total reward 118
# Episode 165: Reached goal in 6 steps with total reward 137
# Episode 166: Reached goal in 4 steps with total reward 118
# Episode 167: Reached goal in 4 steps with total reward 118
# Episode 168: Reached goal in 4 steps with total reward 118
# Episode 169: Reached goal in 4 steps with total reward 118
# Episode 170: Reached goal in 4 steps with total reward 118
# Episode 171: Reached goal in 6 steps with total reward 137
# Episode 172: Reached goal in 4 steps with total reward 118
# Episode 173: Reached goal in 4 steps with total reward 118
# Episode 174: Reached goal in 4 steps with total reward 118
# Episode 175: Reached goal in 4 steps with total reward 118
# Episode 176: Reached goal in 4 steps with total reward 118
# Episode 177: Reached goal in 6 steps with total reward 137
# Episode 178: Reached goal in 4 steps with total reward 118
# Episode 179: Reached goal in 4 steps with total reward 118
# Episode 180: Reached goal in 4 steps with total reward 118
# Episode 181: Reached goal in 4 steps with total reward 118
# Episode 182: Reached goal in 4 steps with total reward 118
# Episode 183: Reached goal in 6 steps with total reward 137
# Episode 184: Reached goal in 4 steps with total reward 118
# Episode 185: Reached goal in 4 steps with total reward 118
# Episode 186: Reached goal in 4 steps with total reward 118
# Episode 187: Reached goal in 4 steps with total reward 118
# Episode 188: Reached goal in 4 steps with total reward 118
# Episode 189: Reached goal in 6 steps with total reward 137
# Episode 190: Reached goal in 4 steps with total reward 118
# Episode 191: Reached goal in 4 steps with total reward 118
# Episode 192: Reached goal in 4 steps with total reward 118
# Episode 193: Reached goal in 4 steps with total reward 118
# Episode 194: Reached goal in 4 steps with total reward 118
# Episode 195: Reached goal in 6 steps with total reward 137
# Episode 196: Reached goal in 4 steps with total reward 118
# Episode 197: Reached goal in 4 steps with total reward 118
# Episode 198: Reached goal in 4 steps with total reward 118
# Episode 199: Reached goal in 4 steps with total reward 118
# Episode 200: Reached goal in 4 steps with total reward 118
# Episode 201: Reached goal in 6 steps with total reward 137
# Episode 202: Reached goal in 4 steps with total reward 118
# Episode 203: Reached goal in 4 steps with total reward 118
# Episode 204: Reached goal in 4 steps with total reward 118
# Episode 205: Reached goal in 4 steps with total reward 118
# Episode 206: Reached goal in 4 steps with total reward 118
# Episode 207: Reached goal in 6 steps with total reward 137
# Episode 208: Reached goal in 4 steps with total reward 118
# Episode 209: Reached goal in 4 steps with total reward 118
# Episode 210: Reached goal in 4 steps with total reward 118
# Episode 211: Reached goal in 4 steps with total reward 118
# Episode 212: Reached goal in 4 steps with total reward 118
# Episode 213: Reached goal in 6 steps with total reward 137
# Episode 214: Reached goal in 4 steps with total reward 118
# Episode 215: Reached goal in 4 steps with total reward 118
# Episode 216: Reached goal in 4 steps with total reward 118
# Episode 217: Reached goal in 4 steps with total reward 118
# Episode 218: Reached goal in 4 steps with total reward 118
# Episode 219: Reached goal in 6 steps with total reward 137
# Episode 220: Reached goal in 4 steps with total reward 118
# Episode 221: Reached goal in 4 steps with total reward 118
# Episode 222: Reached goal in 4 steps with total reward 118
# Episode 223: Reached goal in 4 steps with total reward 118
# Episode 224: Reached goal in 4 steps with total reward 118
# Episode 225: Reached goal in 6 steps with total reward 137
# Episode 226: Reached goal in 4 steps with total reward 118
# Episode 227: Reached goal in 4 steps with total reward 118
# Episode 228: Reached goal in 4 steps with total reward 118
# Episode 229: Reached goal in 4 steps with total reward 118
# Episode 230: Reached goal in 4 steps with total reward 118
# Episode 231: Reached goal in 6 steps with total reward 137
# Episode 232: Reached goal in 4 steps with total reward 118
# Episode 233: Reached goal in 4 steps with total reward 118
# Episode 234: Reached goal in 4 steps with total reward 118
# Episode 235: Reached goal in 4 steps with total reward 118
# Episode 236: Reached goal in 4 steps with total reward 118
# Episode 237: Reached goal in 6 steps with total reward 137
# Episode 238: Reached goal in 4 steps with total reward 118
# Episode 239: Reached goal in 4 steps with total reward 118
# Episode 240: Reached goal in 4 steps with total reward 118
# Episode 241: Reached goal in 4 steps with total reward 118
# Episode 242: Reached goal in 4 steps with total reward 118
# Episode 243: Reached goal in 6 steps with total reward 137
# Episode 244: Reached goal in 4 steps with total reward 118
# Episode 245: Reached goal in 4 steps with total reward 118
# Episode 246: Reached goal in 4 steps with total reward 118
# Episode 247: Reached goal in 4 steps with total reward 118
# Episode 248: Reached goal in 4 steps with total reward 118
# Episode 249: Reached goal in 6 steps with total reward 137
# Episode 250: Reached goal in 4 steps with total reward 118
# Episode 251: Reached goal in 4 steps with total reward 118
# Episode 252: Reached goal in 4 steps with total reward 118
# Episode 253: Reached goal in 4 steps with total reward 118
# Episode 254: Reached goal in 4 steps with total reward 118
# Episode 255: Reached goal in 6 steps with total reward 137
# Episode 256: Reached goal in 4 steps with total reward 118
# Episode 257: Reached goal in 4 steps with total reward 118
# Episode 258: Reached goal in 4 steps with total reward 118
# Episode 259: Reached goal in 4 steps with total reward 118
# Episode 260: Reached goal in 4 steps with total reward 118
# Episode 261: Reached goal in 6 steps with total reward 137
# Episode 262: Reached goal in 4 steps with total reward 118
# Episode 263: Reached goal in 4 steps with total reward 118
# Episode 264: Reached goal in 4 steps with total reward 118
# Episode 265: Reached goal in 4 steps with total reward 118
# Episode 266: Reached goal in 4 steps with total reward 118
# Episode 267: Reached goal in 6 steps with total reward 137
# Episode 268: Reached goal in 4 steps with total reward 118
# Episode 269: Reached goal in 4 steps with total reward 118
# Episode 270: Reached goal in 4 steps with total reward 118
# Episode 271: Reached goal in 4 steps with total reward 118
# Episode 272: Reached goal in 4 steps with total reward 118
# Episode 273: Reached goal in 6 steps with total reward 137
# Episode 274: Reached goal in 4 steps with total reward 118
# Episode 275: Reached goal in 4 steps with total reward 118
# Episode 276: Reached goal in 4 steps with total reward 118
# Episode 277: Reached goal in 4 steps with total reward 118
# Episode 278: Reached goal in 4 steps with total reward 118
# Episode 279: Reached goal in 6 steps with total reward 137
# Episode 280: Reached goal in 4 steps with total reward 118
# Episode 281: Reached goal in 4 steps with total reward 118
# Episode 282: Reached goal in 4 steps with total reward 118
# Episode 283: Reached goal in 4 steps with total reward 118
# Episode 284: Reached goal in 4 steps with total reward 118
# Episode 285: Reached goal in 6 steps with total reward 137
# Episode 286: Reached goal in 4 steps with total reward 118
# Episode 287: Reached goal in 4 steps with total reward 118
# Episode 288: Reached goal in 4 steps with total reward 118
# Episode 289: Reached goal in 4 steps with total reward 118
# Episode 290: Reached goal in 4 steps with total reward 118
# Episode 291: Reached goal in 6 steps with total reward 137
# Episode 292: Reached goal in 4 steps with total reward 118
# Episode 293: Reached goal in 4 steps with total reward 118
# Episode 294: Reached goal in 4 steps with total reward 118
# Episode 295: Reached goal in 4 steps with total reward 118
# Episode 296: Reached goal in 4 steps with total reward 118
# Episode 297: Reached goal in 6 steps with total reward 137
# Episode 298: Reached goal in 4 steps with total reward 118
# Episode 299: Reached goal in 4 steps with total reward 118
# Episode 300: Reached goal in 4 steps with total reward 118
# Episode 301: Reached goal in 4 steps with total reward 118
# Episode 302: Reached goal in 4 steps with total reward 118
# Episode 303: Reached goal in 6 steps with total reward 137
# Episode 304: Reached goal in 4 steps with total reward 118
# Episode 305: Reached goal in 4 steps with total reward 118
# Episode 306: Reached goal in 4 steps with total reward 118
# Episode 307: Reached goal in 4 steps with total reward 118
# Episode 308: Reached goal in 4 steps with total reward 118
# Episode 309: Reached goal in 6 steps with total reward 137
# Episode 310: Reached goal in 4 steps with total reward 118
# Episode 311: Reached goal in 4 steps with total reward 118
# Episode 312: Reached goal in 4 steps with total reward 118
# Episode 313: Reached goal in 4 steps with total reward 118
# Episode 314: Reached goal in 4 steps with total reward 118
# Episode 315: Reached goal in 6 steps with total reward 137
# Episode 316: Reached goal in 4 steps with total reward 118
# Episode 317: Reached goal in 4 steps with total reward 118
# Episode 318: Reached goal in 4 steps with total reward 118
# Episode 319: Reached goal in 4 steps with total reward 118
# Episode 320: Reached goal in 4 steps with total reward 118
# Episode 321: Reached goal in 6 steps with total reward 137
# Episode 322: Reached goal in 4 steps with total reward 118
# Episode 323: Reached goal in 4 steps with total reward 118
# Episode 324: Reached goal in 4 steps with total reward 118
# Episode 325: Reached goal in 4 steps with total reward 118
# Episode 326: Reached goal in 4 steps with total reward 118
# Episode 327: Reached goal in 6 steps with total reward 137
# Episode 328: Reached goal in 4 steps with total reward 118
# Episode 329: Reached goal in 4 steps with total reward 118
# Episode 330: Reached goal in 4 steps with total reward 118
# Episode 331: Reached goal in 4 steps with total reward 118
# Episode 332: Reached goal in 4 steps with total reward 118
# Episode 333: Reached goal in 6 steps with total reward 137
# Episode 334: Reached goal in 4 steps with total reward 118
# Episode 335: Reached goal in 4 steps with total reward 118
# Episode 336: Reached goal in 4 steps with total reward 118
# Episode 337: Reached goal in 4 steps with total reward 118
# Episode 338: Reached goal in 4 steps with total reward 118
# Episode 339: Reached goal in 6 steps with total reward 137
# Episode 340: Reached goal in 4 steps with total reward 118
# Episode 341: Reached goal in 4 steps with total reward 118
# Episode 342: Reached goal in 4 steps with total reward 118
# Episode 343: Reached goal in 4 steps with total reward 118
# Episode 344: Reached goal in 4 steps with total reward 118
# Episode 345: Reached goal in 6 steps with total reward 137
# Episode 346: Reached goal in 4 steps with total reward 118
# Episode 347: Reached goal in 4 steps with total reward 118
# Episode 348: Reached goal in 4 steps with total reward 118
# Episode 349: Reached goal in 4 steps with total reward 118
# Episode 350: Reached goal in 4 steps with total reward 118
# Episode 351: Reached goal in 6 steps with total reward 137
# Episode 352: Reached goal in 4 steps with total reward 118
# Episode 353: Reached goal in 4 steps with total reward 118
# Episode 354: Reached goal in 4 steps with total reward 118
# Episode 355: Reached goal in 4 steps with total reward 118
# Episode 356: Reached goal in 4 steps with total reward 118
# Episode 357: Reached goal in 6 steps with total reward 137
# Episode 358: Reached goal in 4 steps with total reward 118
# Episode 359: Reached goal in 4 steps with total reward 118
# Episode 360: Reached goal in 4 steps with total reward 118
# Episode 361: Reached goal in 4 steps with total reward 118
# Episode 362: Reached goal in 4 steps with total reward 118
# Episode 363: Reached goal in 6 steps with total reward 137
# Episode 364: Reached goal in 4 steps with total reward 118
# Episode 365: Reached goal in 4 steps with total reward 118
# Episode 366: Reached goal in 4 steps with total reward 118
# Episode 367: Reached goal in 4 steps with total reward 118
# Episode 368: Reached goal in 4 steps with total reward 118
# Episode 369: Reached goal in 6 steps with total reward 137
# Episode 370: Reached goal in 4 steps with total reward 118
# Episode 371: Reached goal in 4 steps with total reward 118
# Episode 372: Reached goal in 4 steps with total reward 118
# Episode 373: Reached goal in 4 steps with total reward 118
# Episode 374: Reached goal in 4 steps with total reward 118
# Episode 375: Reached goal in 6 steps with total reward 137
# Episode 376: Reached goal in 4 steps with total reward 118
# Episode 377: Reached goal in 4 steps with total reward 118
# Episode 378: Reached goal in 4 steps with total reward 118
# Episode 379: Reached goal in 4 steps with total reward 118
# Episode 380: Reached goal in 4 steps with total reward 118
# Episode 381: Reached goal in 6 steps with total reward 137
# Episode 382: Reached goal in 4 steps with total reward 118
# Episode 383: Reached goal in 4 steps with total reward 118
# Episode 384: Reached goal in 4 steps with total reward 118
# Episode 385: Reached goal in 4 steps with total reward 118
# Episode 386: Reached goal in 4 steps with total reward 118
# Episode 387: Reached goal in 6 steps with total reward 137
# Episode 388: Reached goal in 4 steps with total reward 118
# Episode 389: Reached goal in 4 steps with total reward 118
# Episode 390: Reached goal in 4 steps with total reward 118
# Episode 391: Reached goal in 4 steps with total reward 118
# Episode 392: Reached goal in 4 steps with total reward 118
# Episode 393: Reached goal in 6 steps with total reward 137
# Episode 394: Reached goal in 4 steps with total reward 118
# Episode 395: Reached goal in 4 steps with total reward 118
# Episode 396: Reached goal in 4 steps with total reward 118
# Episode 397: Reached goal in 4 steps with total reward 118
# Episode 398: Reached goal in 4 steps with total reward 118
# Episode 399: Reached goal in 6 steps with total reward 137
# Episode 400: Reached goal in 4 steps with total reward 118
# Episode 401: Reached goal in 4 steps with total reward 118
# Episode 402: Reached goal in 4 steps with total reward 118
# Episode 403: Reached goal in 4 steps with total reward 118
# Episode 404: Reached goal in 4 steps with total reward 118
# Episode 405: Reached goal in 6 steps with total reward 137
# Episode 406: Reached goal in 4 steps with total reward 118
# Episode 407: Reached goal in 4 steps with total reward 118
# Episode 408: Reached goal in 4 steps with total reward 118
# Episode 409: Reached goal in 4 steps with total reward 118
# Episode 410: Reached goal in 4 steps with total reward 118
# Episode 411: Reached goal in 6 steps with total reward 137
# Episode 412: Reached goal in 4 steps with total reward 118
# Episode 413: Reached goal in 4 steps with total reward 118
# Episode 414: Reached goal in 4 steps with total reward 118
# Episode 415: Reached goal in 4 steps with total reward 118
# Episode 416: Reached goal in 4 steps with total reward 118
# Episode 417: Reached goal in 6 steps with total reward 137
# Episode 418: Reached goal in 4 steps with total reward 118
# Episode 419: Reached goal in 4 steps with total reward 118
# Episode 420: Reached goal in 4 steps with total reward 118
# Episode 421: Reached goal in 4 steps with total reward 118
# Episode 422: Reached goal in 4 steps with total reward 118
# Episode 423: Reached goal in 6 steps with total reward 137
# Episode 424: Reached goal in 4 steps with total reward 118
# Episode 425: Reached goal in 4 steps with total reward 118
# Episode 426: Reached goal in 4 steps with total reward 118
# Episode 427: Reached goal in 4 steps with total reward 118
# Episode 428: Reached goal in 4 steps with total reward 118
# Episode 429: Reached goal in 6 steps with total reward 137
# Episode 430: Reached goal in 4 steps with total reward 118
# Episode 431: Reached goal in 4 steps with total reward 118
# Episode 432: Reached goal in 4 steps with total reward 118
# Episode 433: Reached goal in 4 steps with total reward 118
# Episode 434: Reached goal in 4 steps with total reward 118
# Episode 435: Reached goal in 6 steps with total reward 137
# Episode 436: Reached goal in 4 steps with total reward 118
# Episode 437: Reached goal in 4 steps with total reward 118
# Episode 438: Reached goal in 4 steps with total reward 118
# Episode 439: Reached goal in 4 steps with total reward 118
# Episode 440: Reached goal in 4 steps with total reward 118
# Episode 441: Reached goal in 6 steps with total reward 137
# Episode 442: Reached goal in 4 steps with total reward 118
# Episode 443: Reached goal in 4 steps with total reward 118
# Episode 444: Reached goal in 4 steps with total reward 118
# Episode 445: Reached goal in 4 steps with total reward 118
# Episode 446: Reached goal in 4 steps with total reward 118
# Episode 447: Reached goal in 6 steps with total reward 137
# Episode 448: Reached goal in 4 steps with total reward 118
# Episode 449: Reached goal in 4 steps with total reward 118
# Episode 450: Reached goal in 4 steps with total reward 118
# Episode 451: Reached goal in 4 steps with total reward 118
# Episode 452: Reached goal in 4 steps with total reward 118
# Episode 453: Reached goal in 6 steps with total reward 137
# Episode 454: Reached goal in 4 steps with total reward 118
# Episode 455: Reached goal in 4 steps with total reward 118
# Episode 456: Reached goal in 4 steps with total reward 118
# Episode 457: Reached goal in 4 steps with total reward 118
# Episode 458: Reached goal in 4 steps with total reward 118
# Episode 459: Reached goal in 6 steps with total reward 137
# Episode 460: Reached goal in 4 steps with total reward 118
# Episode 461: Reached goal in 4 steps with total reward 118
# Episode 462: Reached goal in 4 steps with total reward 118
# Episode 463: Reached goal in 4 steps with total reward 118
# Episode 464: Reached goal in 4 steps with total reward 118
# Episode 465: Reached goal in 6 steps with total reward 137
# Episode 466: Reached goal in 4 steps with total reward 118
# Episode 467: Reached goal in 4 steps with total reward 118
# Episode 468: Reached goal in 4 steps with total reward 118
# Episode 469: Reached goal in 4 steps with total reward 118
# Episode 470: Reached goal in 4 steps with total reward 118
# Episode 471: Reached goal in 6 steps with total reward 137
# Episode 472: Reached goal in 4 steps with total reward 118
# Episode 473: Reached goal in 4 steps with total reward 118
# Episode 474: Reached goal in 4 steps with total reward 118
# Episode 475: Reached goal in 4 steps with total reward 118
# Episode 476: Reached goal in 4 steps with total reward 118
# Episode 477: Reached goal in 6 steps with total reward 137
# Episode 478: Reached goal in 4 steps with total reward 118
# Episode 479: Reached goal in 4 steps with total reward 118
# Episode 480: Reached goal in 4 steps with total reward 118
# Episode 481: Reached goal in 4 steps with total reward 118
# Episode 482: Reached goal in 4 steps with total reward 118
# Episode 483: Reached goal in 6 steps with total reward 137
# Episode 484: Reached goal in 4 steps with total reward 118
# Episode 485: Reached goal in 4 steps with total reward 118
# Episode 486: Reached goal in 4 steps with total reward 118
# Episode 487: Reached goal in 4 steps with total reward 118
# Episode 488: Reached goal in 4 steps with total reward 118
# Episode 489: Reached goal in 6 steps with total reward 137
# Episode 490: Reached goal in 4 steps with total reward 118
# Episode 491: Reached goal in 4 steps with total reward 118
# Episode 492: Reached goal in 4 steps with total reward 118
# Episode 493: Reached goal in 4 steps with total reward 118
# Episode 494: Reached goal in 4 steps with total reward 118
# Episode 495: Reached goal in 6 steps with total reward 137
# Episode 496: Reached goal in 4 steps with total reward 118
# Episode 497: Reached goal in 4 steps with total reward 118
# Episode 498: Reached goal in 4 steps with total reward 118
# Episode 499: Reached goal in 4 steps with total reward 118
# Episode 500: Reached goal in 4 steps with total reward 118
# Episode 501: Reached goal in 6 steps with total reward 137
# Episode 502: Reached goal in 4 steps with total reward 118
# Episode 503: Reached goal in 4 steps with total reward 118
# Episode 504: Reached goal in 4 steps with total reward 118
# Episode 505: Reached goal in 4 steps with total reward 118
# Episode 506: Reached goal in 4 steps with total reward 118
# Episode 507: Reached goal in 6 steps with total reward 137
# Episode 508: Reached goal in 4 steps with total reward 118
# Episode 509: Reached goal in 4 steps with total reward 118
# Episode 510: Reached goal in 4 steps with total reward 118
# Episode 511: Reached goal in 4 steps with total reward 118
# Episode 512: Reached goal in 4 steps with total reward 118
# Episode 513: Reached goal in 6 steps with total reward 137
# Episode 514: Reached goal in 4 steps with total reward 118
# Episode 515: Reached goal in 4 steps with total reward 118
# Episode 516: Reached goal in 4 steps with total reward 118
# Episode 517: Reached goal in 4 steps with total reward 118
# Episode 518: Reached goal in 4 steps with total reward 118
# Episode 519: Reached goal in 6 steps with total reward 137
# Episode 520: Reached goal in 4 steps with total reward 118
# Episode 521: Reached goal in 4 steps with total reward 118
# Episode 522: Reached goal in 4 steps with total reward 118
# Episode 523: Reached goal in 4 steps with total reward 118
# Episode 524: Reached goal in 4 steps with total reward 118
# Episode 525: Reached goal in 6 steps with total reward 137
# Episode 526: Reached goal in 4 steps with total reward 118
# Episode 527: Reached goal in 4 steps with total reward 118
# Episode 528: Reached goal in 4 steps with total reward 118
# Episode 529: Reached goal in 4 steps with total reward 118
# Episode 530: Reached goal in 4 steps with total reward 118
# Episode 531: Reached goal in 6 steps with total reward 137
# Episode 532: Reached goal in 4 steps with total reward 118
# Episode 533: Reached goal in 4 steps with total reward 118
# Episode 534: Reached goal in 4 steps with total reward 118
# Episode 535: Reached goal in 4 steps with total reward 118
# Episode 536: Reached goal in 4 steps with total reward 118
# Episode 537: Reached goal in 6 steps with total reward 137
# Episode 538: Reached goal in 4 steps with total reward 118
# Episode 539: Reached goal in 4 steps with total reward 118
# Episode 540: Reached goal in 4 steps with total reward 118
# Episode 541: Reached goal in 4 steps with total reward 118
# Episode 542: Reached goal in 4 steps with total reward 118
# Episode 543: Reached goal in 6 steps with total reward 137
# Episode 544: Reached goal in 4 steps with total reward 118
# Episode 545: Reached goal in 4 steps with total reward 118
# Episode 546: Reached goal in 4 steps with total reward 118
# Episode 547: Reached goal in 4 steps with total reward 118
# Episode 548: Reached goal in 4 steps with total reward 118
# Episode 549: Reached goal in 6 steps with total reward 137
# Episode 550: Reached goal in 4 steps with total reward 118
# Episode 551: Reached goal in 4 steps with total reward 118
# Episode 552: Reached goal in 4 steps with total reward 118
# Episode 553: Reached goal in 4 steps with total reward 118
# Episode 554: Reached goal in 4 steps with total reward 118
# Episode 555: Reached goal in 6 steps with total reward 137
# Episode 556: Reached goal in 4 steps with total reward 118
# Episode 557: Reached goal in 4 steps with total reward 118
# Episode 558: Reached goal in 4 steps with total reward 118
# Episode 559: Reached goal in 4 steps with total reward 118
# Episode 560: Reached goal in 4 steps with total reward 118
# Episode 561: Reached goal in 6 steps with total reward 137
# Episode 562: Reached goal in 4 steps with total reward 118
# Episode 563: Reached goal in 4 steps with total reward 118
# Episode 564: Reached goal in 4 steps with total reward 118
# Episode 565: Reached goal in 4 steps with total reward 118
# Episode 566: Reached goal in 4 steps with total reward 118
# Episode 567: Reached goal in 6 steps with total reward 137
# Episode 568: Reached goal in 4 steps with total reward 118
# Episode 569: Reached goal in 4 steps with total reward 118
# Episode 570: Reached goal in 4 steps with total reward 118
# Episode 571: Reached goal in 4 steps with total reward 118
# Episode 572: Reached goal in 4 steps with total reward 118
# Episode 573: Reached goal in 6 steps with total reward 137
# Episode 574: Reached goal in 4 steps with total reward 118
# Episode 575: Reached goal in 4 steps with total reward 118
# Episode 576: Reached goal in 4 steps with total reward 118
# Episode 577: Reached goal in 4 steps with total reward 118
# Episode 578: Reached goal in 4 steps with total reward 118
# Episode 579: Reached goal in 6 steps with total reward 137
# Episode 580: Reached goal in 4 steps with total reward 118
# Episode 581: Reached goal in 4 steps with total reward 118
# Episode 582: Reached goal in 4 steps with total reward 118
# Episode 583: Reached goal in 4 steps with total reward 118
# Episode 584: Reached goal in 4 steps with total reward 118
# Episode 585: Reached goal in 6 steps with total reward 137
# Episode 586: Reached goal in 4 steps with total reward 118
# Episode 587: Reached goal in 4 steps with total reward 118
# Episode 588: Reached goal in 4 steps with total reward 118
# Episode 589: Reached goal in 4 steps with total reward 118
# Episode 590: Reached goal in 4 steps with total reward 118
# Episode 591: Reached goal in 6 steps with total reward 137
# Episode 592: Reached goal in 4 steps with total reward 118
# Episode 593: Reached goal in 4 steps with total reward 118
# Episode 594: Reached goal in 4 steps with total reward 118
# Episode 595: Reached goal in 4 steps with total reward 118
# Episode 596: Reached goal in 4 steps with total reward 118
# Episode 597: Reached goal in 6 steps with total reward 137
# Episode 598: Reached goal in 4 steps with total reward 118
# Episode 599: Reached goal in 4 steps with total reward 118
# Episode 600: Reached goal in 4 steps with total reward 118
# Episode 601: Reached goal in 4 steps with total reward 118
# Episode 602: Reached goal in 4 steps with total reward 118
# Episode 603: Reached goal in 6 steps with total reward 137
# Episode 604: Reached goal in 4 steps with total reward 118
# Episode 605: Reached goal in 4 steps with total reward 118
# Episode 606: Reached goal in 4 steps with total reward 118
# Episode 607: Reached goal in 4 steps with total reward 118
# Episode 608: Reached goal in 4 steps with total reward 118
# Episode 609: Reached goal in 6 steps with total reward 137
# Episode 610: Reached goal in 4 steps with total reward 118
# Episode 611: Reached goal in 4 steps with total reward 118
# Episode 612: Reached goal in 4 steps with total reward 118
# Episode 613: Reached goal in 4 steps with total reward 118
# Episode 614: Reached goal in 4 steps with total reward 118
# Episode 615: Reached goal in 6 steps with total reward 137
# Episode 616: Reached goal in 4 steps with total reward 118
# Episode 617: Reached goal in 4 steps with total reward 118
# Episode 618: Reached goal in 4 steps with total reward 118
# Episode 619: Reached goal in 4 steps with total reward 118
# Episode 620: Reached goal in 4 steps with total reward 118
# Episode 621: Reached goal in 6 steps with total reward 137
# Episode 622: Reached goal in 4 steps with total reward 118
# Episode 623: Reached goal in 4 steps with total reward 118
# Episode 624: Reached goal in 4 steps with total reward 118
# Episode 625: Reached goal in 4 steps with total reward 118
# Episode 626: Reached goal in 4 steps with total reward 118
# Episode 627: Reached goal in 6 steps with total reward 137
# Episode 628: Reached goal in 4 steps with total reward 118
# Episode 629: Reached goal in 4 steps with total reward 118
# Episode 630: Reached goal in 4 steps with total reward 118
# Episode 631: Reached goal in 4 steps with total reward 118
# Episode 632: Reached goal in 4 steps with total reward 118
# Episode 633: Reached goal in 6 steps with total reward 137
# Episode 634: Reached goal in 4 steps with total reward 118
# Episode 635: Reached goal in 4 steps with total reward 118
# Episode 636: Reached goal in 4 steps with total reward 118
# Episode 637: Reached goal in 4 steps with total reward 118
# Episode 638: Reached goal in 4 steps with total reward 118
# Episode 639: Reached goal in 6 steps with total reward 137
# Episode 640: Reached goal in 4 steps with total reward 118
# Episode 641: Reached goal in 4 steps with total reward 118
# Episode 642: Reached goal in 4 steps with total reward 118
# Episode 643: Reached goal in 4 steps with total reward 118
# Episode 644: Reached goal in 4 steps with total reward 118
# Episode 645: Reached goal in 6 steps with total reward 137
# Episode 646: Reached goal in 4 steps with total reward 118
# Episode 647: Reached goal in 4 steps with total reward 118
# Episode 648: Reached goal in 4 steps with total reward 118
# Episode 649: Reached goal in 4 steps with total reward 118
# Episode 650: Reached goal in 4 steps with total reward 118
# Episode 651: Reached goal in 6 steps with total reward 137
# Episode 652: Reached goal in 4 steps with total reward 118
# Episode 653: Reached goal in 4 steps with total reward 118
# Episode 654: Reached goal in 4 steps with total reward 118
# Episode 655: Reached goal in 4 steps with total reward 118
# Episode 656: Reached goal in 4 steps with total reward 118
# Episode 657: Reached goal in 6 steps with total reward 137
# Episode 658: Reached goal in 4 steps with total reward 118
# Episode 659: Reached goal in 4 steps with total reward 118
# Episode 660: Reached goal in 4 steps with total reward 118
# Episode 661: Reached goal in 4 steps with total reward 118
# Episode 662: Reached goal in 4 steps with total reward 118
# Episode 663: Reached goal in 6 steps with total reward 137
# Episode 664: Reached goal in 4 steps with total reward 118
# Episode 665: Reached goal in 4 steps with total reward 118
# Episode 666: Reached goal in 4 steps with total reward 118
# Episode 667: Reached goal in 4 steps with total reward 118
# Episode 668: Reached goal in 6 steps with total reward 137
# Episode 669: Reached goal in 4 steps with total reward 118
# Episode 670: Reached goal in 4 steps with total reward 118
# Episode 671: Reached goal in 6 steps with total reward 137
# Episode 672: Reached goal in 4 steps with total reward 118
# Episode 673: Reached goal in 4 steps with total reward 118
# Episode 674: Reached goal in 6 steps with total reward 137
# Episode 675: Reached goal in 4 steps with total reward 118
# Episode 676: Reached goal in 4 steps with total reward 118
# Episode 677: Reached goal in 6 steps with total reward 137
# Episode 678: Reached goal in 4 steps with total reward 118
# Episode 679: Reached goal in 4 steps with total reward 118
# Episode 680: Reached goal in 6 steps with total reward 137
# Episode 681: Reached goal in 4 steps with total reward 118
# Episode 682: Reached goal in 4 steps with total reward 118
# Episode 683: Reached goal in 6 steps with total reward 137
# Episode 684: Reached goal in 4 steps with total reward 118
# Episode 685: Reached goal in 4 steps with total reward 118
# Episode 686: Reached goal in 6 steps with total reward 137
# Episode 687: Reached goal in 4 steps with total reward 118
# Episode 688: Reached goal in 4 steps with total reward 118
# Episode 689: Reached goal in 6 steps with total reward 137
# Episode 690: Reached goal in 4 steps with total reward 118
# Episode 691: Reached goal in 4 steps with total reward 118
# Episode 692: Reached goal in 6 steps with total reward 137
# Episode 693: Reached goal in 4 steps with total reward 118
# Episode 694: Reached goal in 4 steps with total reward 118
# Episode 695: Reached goal in 6 steps with total reward 137
# Episode 696: Reached goal in 4 steps with total reward 118
# Episode 697: Reached goal in 4 steps with total reward 118
# Episode 698: Reached goal in 6 steps with total reward 137
# Episode 699: Reached goal in 4 steps with total reward 118
# Episode 700: Reached goal in 4 steps with total reward 118
# Episode 701: Reached goal in 6 steps with total reward 137
# Episode 702: Reached goal in 4 steps with total reward 118
# Episode 703: Reached goal in 4 steps with total reward 118
# Episode 704: Reached goal in 6 steps with total reward 137
# Episode 705: Reached goal in 4 steps with total reward 118
# Episode 706: Reached goal in 4 steps with total reward 118
# Episode 707: Reached goal in 6 steps with total reward 137
# Episode 708: Reached goal in 4 steps with total reward 118
# Episode 709: Reached goal in 4 steps with total reward 118
# Episode 710: Reached goal in 6 steps with total reward 137
# Episode 711: Reached goal in 4 steps with total reward 118
# Episode 712: Reached goal in 4 steps with total reward 118
# Episode 713: Reached goal in 6 steps with total reward 137
# Episode 714: Reached goal in 4 steps with total reward 118
# Episode 715: Reached goal in 4 steps with total reward 118
# Episode 716: Reached goal in 6 steps with total reward 137
# Episode 717: Reached goal in 4 steps with total reward 118
# Episode 718: Reached goal in 4 steps with total reward 118
# Episode 719: Reached goal in 6 steps with total reward 137
# Episode 720: Reached goal in 4 steps with total reward 118
# Episode 721: Reached goal in 4 steps with total reward 118
# Episode 722: Reached goal in 6 steps with total reward 137
# Episode 723: Reached goal in 4 steps with total reward 118
# Episode 724: Reached goal in 4 steps with total reward 118
# Episode 725: Reached goal in 6 steps with total reward 137
# Episode 726: Reached goal in 4 steps with total reward 118
# Episode 727: Reached goal in 4 steps with total reward 118
# Episode 728: Reached goal in 6 steps with total reward 137
# Episode 729: Reached goal in 4 steps with total reward 118
# Episode 730: Reached goal in 4 steps with total reward 118
# Episode 731: Reached goal in 6 steps with total reward 137
# Episode 732: Reached goal in 4 steps with total reward 118
# Episode 733: Reached goal in 4 steps with total reward 118
# Episode 734: Reached goal in 6 steps with total reward 137
# Episode 735: Reached goal in 4 steps with total reward 118
# Episode 736: Reached goal in 4 steps with total reward 118
# Episode 737: Reached goal in 6 steps with total reward 137
# Episode 738: Reached goal in 4 steps with total reward 118
# Episode 739: Reached goal in 4 steps with total reward 118
# Episode 740: Reached goal in 6 steps with total reward 137
# Episode 741: Reached goal in 4 steps with total reward 118
# Episode 742: Reached goal in 4 steps with total reward 118
# Episode 743: Reached goal in 6 steps with total reward 137
# Episode 744: Reached goal in 4 steps with total reward 118
# Episode 745: Reached goal in 4 steps with total reward 118
# Episode 746: Reached goal in 6 steps with total reward 137
# Episode 747: Reached goal in 4 steps with total reward 118
# Episode 748: Reached goal in 4 steps with total reward 118
# Episode 749: Reached goal in 6 steps with total reward 137
# Episode 750: Reached goal in 4 steps with total reward 118
# Episode 751: Reached goal in 4 steps with total reward 118
# Episode 752: Reached goal in 6 steps with total reward 137
# Episode 753: Reached goal in 4 steps with total reward 118
# Episode 754: Reached goal in 4 steps with total reward 118
# Episode 755: Reached goal in 6 steps with total reward 137
# Episode 756: Reached goal in 4 steps with total reward 118
# Episode 757: Reached goal in 4 steps with total reward 118
# Episode 758: Reached goal in 6 steps with total reward 137
# Episode 759: Reached goal in 4 steps with total reward 118
# Episode 760: Reached goal in 4 steps with total reward 118
# Episode 761: Reached goal in 6 steps with total reward 137
# Episode 762: Reached goal in 4 steps with total reward 118
# Episode 763: Reached goal in 4 steps with total reward 118
# Episode 764: Reached goal in 6 steps with total reward 137
# Episode 765: Reached goal in 4 steps with total reward 118
# Episode 766: Reached goal in 4 steps with total reward 118
# Episode 767: Reached goal in 6 steps with total reward 137
# Episode 768: Reached goal in 4 steps with total reward 118
# Episode 769: Reached goal in 4 steps with total reward 118
# Episode 770: Reached goal in 6 steps with total reward 137
# Episode 771: Reached goal in 4 steps with total reward 118
# Episode 772: Reached goal in 4 steps with total reward 118
# Episode 773: Reached goal in 6 steps with total reward 137
# Episode 774: Reached goal in 4 steps with total reward 118
# Episode 775: Reached goal in 4 steps with total reward 118
# Episode 776: Reached goal in 6 steps with total reward 137
# Episode 777: Reached goal in 4 steps with total reward 118
# Episode 778: Reached goal in 4 steps with total reward 118
# Episode 779: Reached goal in 6 steps with total reward 137
# Episode 780: Reached goal in 4 steps with total reward 118
# Episode 781: Reached goal in 4 steps with total reward 118
# Episode 782: Reached goal in 6 steps with total reward 137
# Episode 783: Reached goal in 4 steps with total reward 118
# Episode 784: Reached goal in 4 steps with total reward 118
# Episode 785: Reached goal in 6 steps with total reward 137
# Episode 786: Reached goal in 4 steps with total reward 118
# Episode 787: Reached goal in 4 steps with total reward 118
# Episode 788: Reached goal in 6 steps with total reward 137
# Episode 789: Reached goal in 4 steps with total reward 118
# Episode 790: Reached goal in 4 steps with total reward 118
# Episode 791: Reached goal in 6 steps with total reward 137
# Episode 792: Reached goal in 4 steps with total reward 118
# Episode 793: Reached goal in 4 steps with total reward 118
# Episode 794: Reached goal in 6 steps with total reward 137
# Episode 795: Reached goal in 4 steps with total reward 118
# Episode 796: Reached goal in 4 steps with total reward 118
# Episode 797: Reached goal in 6 steps with total reward 137
# Episode 798: Reached goal in 4 steps with total reward 118
# Episode 799: Reached goal in 4 steps with total reward 118
# Episode 800: Reached goal in 6 steps with total reward 137
# Episode 801: Reached goal in 4 steps with total reward 118
# Episode 802: Reached goal in 4 steps with total reward 118
# Episode 803: Reached goal in 6 steps with total reward 137
# Episode 804: Reached goal in 4 steps with total reward 118
# Episode 805: Reached goal in 4 steps with total reward 118
# Episode 806: Reached goal in 6 steps with total reward 137
# Episode 807: Reached goal in 4 steps with total reward 118
# Episode 808: Reached goal in 4 steps with total reward 118
# Episode 809: Reached goal in 6 steps with total reward 137
# Episode 810: Reached goal in 4 steps with total reward 118
# Episode 811: Reached goal in 4 steps with total reward 118
# Episode 812: Reached goal in 6 steps with total reward 137
# Episode 813: Reached goal in 4 steps with total reward 118
# Episode 814: Reached goal in 4 steps with total reward 118
# Episode 815: Reached goal in 6 steps with total reward 137
# Episode 816: Reached goal in 4 steps with total reward 118
# Episode 817: Reached goal in 4 steps with total reward 118
# Episode 818: Reached goal in 6 steps with total reward 137
# Episode 819: Reached goal in 4 steps with total reward 118
# Episode 820: Reached goal in 4 steps with total reward 118
# Episode 821: Reached goal in 6 steps with total reward 137
# Episode 822: Reached goal in 4 steps with total reward 118
# Episode 823: Reached goal in 4 steps with total reward 118
# Episode 824: Reached goal in 6 steps with total reward 137
# Episode 825: Reached goal in 4 steps with total reward 118
# Episode 826: Reached goal in 4 steps with total reward 118
# Episode 827: Reached goal in 6 steps with total reward 137
# Episode 828: Reached goal in 4 steps with total reward 118
# Episode 829: Reached goal in 4 steps with total reward 118
# Episode 830: Reached goal in 6 steps with total reward 137
# Episode 831: Reached goal in 4 steps with total reward 118
# Episode 832: Reached goal in 4 steps with total reward 118
# Episode 833: Reached goal in 6 steps with total reward 137
# Episode 834: Reached goal in 4 steps with total reward 118
# Episode 835: Reached goal in 4 steps with total reward 118
# Episode 836: Reached goal in 6 steps with total reward 137
# Episode 837: Reached goal in 4 steps with total reward 118
# Episode 838: Reached goal in 4 steps with total reward 118
# Episode 839: Reached goal in 6 steps with total reward 137
# Episode 840: Reached goal in 4 steps with total reward 118
# Episode 841: Reached goal in 4 steps with total reward 118
# Episode 842: Reached goal in 6 steps with total reward 137
# Episode 843: Reached goal in 4 steps with total reward 118
# Episode 844: Reached goal in 4 steps with total reward 118
# Episode 845: Reached goal in 6 steps with total reward 137
# Episode 846: Reached goal in 4 steps with total reward 118
# Episode 847: Reached goal in 4 steps with total reward 118
# Episode 848: Reached goal in 6 steps with total reward 137
# Episode 849: Reached goal in 4 steps with total reward 118
# Episode 850: Reached goal in 4 steps with total reward 118
# Episode 851: Reached goal in 6 steps with total reward 137
# Episode 852: Reached goal in 4 steps with total reward 118
# Episode 853: Reached goal in 4 steps with total reward 118
# Episode 854: Reached goal in 6 steps with total reward 137
# Episode 855: Reached goal in 4 steps with total reward 118
# Episode 856: Reached goal in 4 steps with total reward 118
# Episode 857: Reached goal in 6 steps with total reward 137
# Episode 858: Reached goal in 4 steps with total reward 118
# Episode 859: Reached goal in 4 steps with total reward 118
# Episode 860: Reached goal in 6 steps with total reward 137
# Episode 861: Reached goal in 4 steps with total reward 118
# Episode 862: Reached goal in 4 steps with total reward 118
# Episode 863: Reached goal in 6 steps with total reward 137
# Episode 864: Reached goal in 4 steps with total reward 118
# Episode 865: Reached goal in 4 steps with total reward 118
# Episode 866: Reached goal in 6 steps with total reward 137
# Episode 867: Reached goal in 4 steps with total reward 118
# Episode 868: Reached goal in 4 steps with total reward 118
# Episode 869: Reached goal in 6 steps with total reward 137
# Episode 870: Reached goal in 4 steps with total reward 118
# Episode 871: Reached goal in 4 steps with total reward 118
# Episode 872: Reached goal in 6 steps with total reward 137
# Episode 873: Reached goal in 4 steps with total reward 118
# Episode 874: Reached goal in 4 steps with total reward 118
# Episode 875: Reached goal in 6 steps with total reward 137
# Episode 876: Reached goal in 4 steps with total reward 118
# Episode 877: Reached goal in 4 steps with total reward 118
# Episode 878: Reached goal in 6 steps with total reward 137
# Episode 879: Reached goal in 4 steps with total reward 118
# Episode 880: Reached goal in 4 steps with total reward 118
# Episode 881: Reached goal in 6 steps with total reward 137
# Episode 882: Reached goal in 4 steps with total reward 118
# Episode 883: Reached goal in 4 steps with total reward 118
# Episode 884: Reached goal in 6 steps with total reward 137
# Episode 885: Reached goal in 4 steps with total reward 118
# Episode 886: Reached goal in 4 steps with total reward 118
# Episode 887: Reached goal in 6 steps with total reward 137
# Episode 888: Reached goal in 4 steps with total reward 118
# Episode 889: Reached goal in 4 steps with total reward 118
# Episode 890: Reached goal in 6 steps with total reward 137
# Episode 891: Reached goal in 4 steps with total reward 118
# Episode 892: Reached goal in 4 steps with total reward 118
# Episode 893: Reached goal in 6 steps with total reward 137
# Episode 894: Reached goal in 4 steps with total reward 118
# Episode 895: Reached goal in 4 steps with total reward 118
# Episode 896: Reached goal in 6 steps with total reward 137
# Episode 897: Reached goal in 4 steps with total reward 118
# Episode 898: Reached goal in 4 steps with total reward 118
# Episode 899: Reached goal in 6 steps with total reward 137
# Episode 900: Reached goal in 4 steps with total reward 118
# Episode 901: Reached goal in 4 steps with total reward 118
# Episode 902: Reached goal in 6 steps with total reward 137
# Episode 903: Reached goal in 4 steps with total reward 118
# Episode 904: Reached goal in 4 steps with total reward 118
# Episode 905: Reached goal in 6 steps with total reward 137
# Episode 906: Reached goal in 4 steps with total reward 118
# Episode 907: Reached goal in 4 steps with total reward 118
# Episode 908: Reached goal in 6 steps with total reward 137
# Episode 909: Reached goal in 4 steps with total reward 118
# Episode 910: Reached goal in 4 steps with total reward 118
# Episode 911: Reached goal in 6 steps with total reward 137
# Episode 912: Reached goal in 4 steps with total reward 118
# Episode 913: Reached goal in 4 steps with total reward 118
# Episode 914: Reached goal in 6 steps with total reward 137
# Episode 915: Reached goal in 4 steps with total reward 118
# Episode 916: Reached goal in 4 steps with total reward 118
# Episode 917: Reached goal in 6 steps with total reward 137
# Episode 918: Reached goal in 4 steps with total reward 118
# Episode 919: Reached goal in 4 steps with total reward 118
# Episode 920: Reached goal in 6 steps with total reward 137
# Episode 921: Reached goal in 4 steps with total reward 118
# Episode 922: Reached goal in 4 steps with total reward 118
# Episode 923: Reached goal in 6 steps with total reward 137
# Episode 924: Reached goal in 4 steps with total reward 118
# Episode 925: Reached goal in 4 steps with total reward 118
# Episode 926: Reached goal in 6 steps with total reward 137
# Episode 927: Reached goal in 4 steps with total reward 118
# Episode 928: Reached goal in 4 steps with total reward 118
# Episode 929: Reached goal in 6 steps with total reward 137
# Episode 930: Reached goal in 4 steps with total reward 118
# Episode 931: Reached goal in 4 steps with total reward 118
# Episode 932: Reached goal in 6 steps with total reward 137
# Episode 933: Reached goal in 4 steps with total reward 118
# Episode 934: Reached goal in 4 steps with total reward 118
# Episode 935: Reached goal in 6 steps with total reward 137
# Episode 936: Reached goal in 4 steps with total reward 118
# Episode 937: Reached goal in 4 steps with total reward 118
# Episode 938: Reached goal in 6 steps with total reward 137
# Episode 939: Reached goal in 4 steps with total reward 118
# Episode 940: Reached goal in 4 steps with total reward 118
# Episode 941: Reached goal in 6 steps with total reward 137
# Episode 942: Reached goal in 4 steps with total reward 118
# Episode 943: Reached goal in 4 steps with total reward 118
# Episode 944: Reached goal in 6 steps with total reward 137
# Episode 945: Reached goal in 4 steps with total reward 118
# Episode 946: Reached goal in 4 steps with total reward 118
# Episode 947: Reached goal in 6 steps with total reward 137
# Episode 948: Reached goal in 4 steps with total reward 118
# Episode 949: Reached goal in 4 steps with total reward 118
# Episode 950: Reached goal in 6 steps with total reward 137
# Episode 951: Reached goal in 4 steps with total reward 118
# Episode 952: Reached goal in 4 steps with total reward 118
# Episode 953: Reached goal in 6 steps with total reward 137
# Episode 954: Reached goal in 4 steps with total reward 118
# Episode 955: Reached goal in 4 steps with total reward 118
# Episode 956: Reached goal in 6 steps with total reward 137
# Episode 957: Reached goal in 4 steps with total reward 118
# Episode 958: Reached goal in 4 steps with total reward 118
# Episode 959: Reached goal in 6 steps with total reward 137
# Episode 960: Reached goal in 4 steps with total reward 118
# Episode 961: Reached goal in 4 steps with total reward 118
# Episode 962: Reached goal in 6 steps with total reward 137
# Episode 963: Reached goal in 4 steps with total reward 118
# Episode 964: Reached goal in 4 steps with total reward 118
# Episode 965: Reached goal in 6 steps with total reward 137
# Episode 966: Reached goal in 4 steps with total reward 118
# Episode 967: Reached goal in 4 steps with total reward 118
# Episode 968: Reached goal in 6 steps with total reward 137
# Episode 969: Reached goal in 4 steps with total reward 118
# Episode 970: Reached goal in 4 steps with total reward 118
# Episode 971: Reached goal in 6 steps with total reward 137
# Episode 972: Reached goal in 4 steps with total reward 118
# Episode 973: Reached goal in 4 steps with total reward 118
# Episode 974: Reached goal in 6 steps with total reward 137
# Episode 975: Reached goal in 4 steps with total reward 118
# Episode 976: Reached goal in 4 steps with total reward 118
# Episode 977: Reached goal in 6 steps with total reward 137
# Episode 978: Reached goal in 4 steps with total reward 118
# Episode 979: Reached goal in 4 steps with total reward 118
# Episode 980: Reached goal in 6 steps with total reward 137
# Episode 981: Reached goal in 4 steps with total reward 118
# Episode 982: Reached goal in 4 steps with total reward 118
# Episode 983: Reached goal in 6 steps with total reward 137
# Episode 984: Reached goal in 4 steps with total reward 118
# Episode 985: Reached goal in 4 steps with total reward 118
# Episode 986: Reached goal in 6 steps with total reward 137
# Episode 987: Reached goal in 4 steps with total reward 118
# Episode 988: Reached goal in 4 steps with total reward 118
# Episode 989: Reached goal in 6 steps with total reward 137
# Episode 990: Reached goal in 4 steps with total reward 118
# Episode 991: Reached goal in 4 steps with total reward 118
# Episode 992: Reached goal in 6 steps with total reward 137
# Episode 993: Reached goal in 4 steps with total reward 118
# Episode 994: Reached goal in 4 steps with total reward 118
# Episode 995: Reached goal in 6 steps with total reward 137
# Episode 996: Reached goal in 4 steps with total reward 118
# Episode 997: Reached goal in 4 steps with total reward 118
# Episode 998: Reached goal in 6 steps with total reward 137
# Episode 999: Reached goal in 4 steps with total reward 118
# Episode 1000: Reached goal in 4 steps with total reward 118

# %%
# Now play one episode using the learned Q-table without exploration, avoiding invalid moves
agent.play_one_episode()
# Out:
# Step 1: Moving right from (0, 0)
# Step 2: Moving down from (0, 1)
# Step 3: Moving left from (1, 1)
# Step 4: Moving down from (1, 0)
# Step 5: Moving right from (2, 0)
# Step 6: Moving right from (2, 1)
# Reached the goal in 6 steps with total reward: 137

# %%
maze_game.render_animation()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img80032c861fd0464d8fb8a9216c398e3c">
#   <div class="anim-controls">
#     <input id="_anim_slider80032c861fd0464d8fb8a9216c398e3c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim80032c861fd0464d8fb8a9216c398e3c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim80032c861fd0464d8fb8a9216c398e3c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim80032c861fd0464d8fb8a9216c398e3c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim80032c861fd0464d8fb8a9216c398e3c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim80032c861fd0464d8fb8a9216c398e3c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim80032c861fd0464d8fb8a9216c398e3c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim80032c861fd0464d8fb8a9216c398e3c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim80032c861fd0464d8fb8a9216c398e3c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim80032c861fd0464d8fb8a9216c398e3c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim80032c861fd0464d8fb8a9216c398e3c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select80032c861fd0464d8fb8a9216c398e3c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_80032c861fd0464d8fb8a9216c398e3c"
#              >
#       <label for="_anim_radio1_80032c861fd0464d8fb8a9216c398e3c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_80032c861fd0464d8fb8a9216c398e3c"
#              checked>
#       <label for="_anim_radio2_80032c861fd0464d8fb8a9216c398e3c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_80032c861fd0464d8fb8a9216c398e3c"
#              >
#       <label for="_anim_radio3_80032c861fd0464d8fb8a9216c398e3c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img80032c861fd0464d8fb8a9216c398e3c";
#     var slider_id = "_anim_slider80032c861fd0464d8fb8a9216c398e3c";
#     var loop_select_id = "_anim_loop_select80032c861fd0464d8fb8a9216c398e3c";
#     var frames = new Array(7);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABYHElEQV
