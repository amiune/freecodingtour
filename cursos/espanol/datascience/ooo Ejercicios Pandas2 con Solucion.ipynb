# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Cargar de csv
# Cargar los archivos:
# - diabetes_v2/diabetes_train_analysis.csv
# - diabetes_v2/diabetes_train_info.csv
# en dataframes

# %%
df_ana = pd.read_csv('diabetes_v2/diabetes_train_analysis.csv')
df_inf = pd.read_csv('diabetes_v2/diabetes_train_info.csv')

# %% [markdown]
# ## Ver las primeras filas de ambos dataframes

# %%
df_ana.head()
# Out:
#       id cholesterol gluc  smoke  alco  active pressure  diabetes
# 0  62538         low  low      0     0       1   100/80         0
# 1  49159         low  low      0     0       1   120/82         0
# 2  60683         low  low      0     0       1   120/80         0
# 3  42924         low  low      0     0       0   120\80         0
# 4  52888         low  low      0     0       0   120/80         0

# %%
df_inf.head()
# Out:
#    id    age  height  weight gender
# 0   0     50     168    62.0      f
# 1   1     55     156    85.0      m
# 2   2  18857     165    64.0   male
# 3   3  17623     169    82.0      f
# 4   4     47     156    56.0      m

# %% [markdown]
# ## Unir dataframes
# Unir ambos dataframes por medio del campo id y eliminar dicho campo

# %%
df = pd.merge(df_ana,df_inf,on="id")
df = df.drop("id",axis=1)

# %%
df.head()
# Out:
#   cholesterol gluc  smoke  alco  active pressure  diabetes    age  height  \
# 0         low  low      0     0       1   100/80         0     54     169
# 1         low  low      0     0       1   120/82         0     49     165
# 2         low  low      0     0       1   120/80         0  21962     170
# 3         low  low      0     0       0   120\80         0  20287     169
# 4         low  low      0     0       0   120/80         0  16202     166
#
#    weight gender
# 0    76.0      f
# 1    65.0      m
# 2    56.0      m
# 3    62.0      m
# 4    67.0   male

# %% [markdown]
# ## Corregir strings de pressure
# El campo pressure a veces tiene el caracter \ como separador y a veces /
# Unificar el formato

# %%
df.pressure = df.pressure.str.replace("\\","/",regex=False)

# %%
df.head()
# Out:
#   cholesterol gluc  smoke  alco  active pressure  diabetes    age  height  \
# 0         low  low      0     0       1   100/80         0     54     169
# 1         low  low      0     0       1   120/82         0     49     165
# 2         low  low      0     0       1   120/80         0  21962     170
# 3         low  low      0     0       0   120/80         0  20287     169
# 4         low  low      0     0       0   120/80         0  16202     166
#
#    weight gender
# 0    76.0      f
# 1    65.0      m
# 2    56.0      m
# 3    62.0      m
# 4    67.0   male

# %% [markdown]
# ## Separar el campo pressure en dos
# Utilizar el separador del campo presure para dividir en dos dicho campo y luego eliminarlo

# %%
df[["pressure1","pressure2"]] = df.pressure.str.split("/", expand=True)
df = df.drop("pressure",axis=1)

# %%
df.head()
# Out:
#   cholesterol gluc  smoke  alco  active  diabetes    age  height  weight  \
# 0         low  low      0     0       1         0     54     169    76.0
# 1         low  low      0     0       1         0     49     165    65.0
# 2         low  low      0     0       1         0  21962     170    56.0
# 3         low  low      0     0       0         0  20287     169    62.0
# 4         low  low      0     0       0         0  16202     166    67.0
#
#   gender pressure1 pressure2
# 0      f       100        80
# 1      m       120        82
# 2      m       120        80
# 3      m       120        80
# 4   male       120        80

# %% [markdown]
# ## Unificar el formato del campo gender
# Femenino a veces se encuentra como female y a veces como f
# Masculino a veces se encuentra como male y a veces como m
# Unificar la notacion

# %%
df.gender = df.gender.str.replace("female","f")
df.gender = df.gender.str.replace("male","m")

# %%
df.head()
# Out:
#   cholesterol gluc  smoke  alco  active  diabetes    age  height  weight  \
# 0         low  low      0     0       1         0     54     169    76.0
# 1         low  low      0     0       1         0     49     165    65.0
# 2         low  low      0     0       1         0  21962     170    56.0
# 3         low  low      0     0       0         0  20287     169    62.0
# 4         low  low      0     0       0         0  16202     166    67.0
#
#   gender pressure1 pressure2
# 0      f       100        80
# 1      m       120        82
# 2      m       120        80
# 3      m       120        80
# 4      m       120        80

# %% [markdown]
# ## Unificar el campo edad
# El campo edad a veces se encuentra expresado en dias y a veces en años. Unificarlo

# %%
df.loc[df["age"] < 150, "age"] = df.loc[df["age"] < 150, "age"] * 365

# %%
df.head()
# Out:
#   cholesterol gluc  smoke  alco  active  diabetes    age  height  weight  \
# 0         low  low      0     0       1         0  19710     169    76.0
# 1         low  low      0     0       1         0  17885     165    65.0
# 2         low  low      0     0       1         0  21962     170    56.0
# 3         low  low      0     0       0         0  20287     169    62.0
# 4         low  low      0     0       0         0  16202     166    67.0
#
#   gender pressure1 pressure2
# 0      f       100        80
# 1      m       120        82
# 2      m       120        80
# 3      m       120        80
# 4      m       120        80

# %% [markdown]
# ## Verificar si hay valores faltantes en algun campo

# %%
df.isna().sum()
# Out:
# cholesterol       0
# gluc              0
# smoke             0
# alco              0
# active            0
# diabetes          0
# age               0
# height            0
# weight         1998
# gender            0
# pressure1         0
# pressure2         0
# dtype: int64

# %% [markdown]
# ## Reemplazar valores faltantes
# Reemplazar los valores faltantes del campo weight por la media de dicho campo

# %%
df.weight.fillna(df.weight.mean(), inplace=True)

# %%
df.head()
# Out:
#   cholesterol gluc  smoke  alco  active  diabetes    age  height  weight  \
# 0         low  low      0     0       1         0  19710     169    76.0
# 1         low  low      0     0       1         0  17885     165    65.0
# 2         low  low      0     0       1         0  21962     170    56.0
# 3         low  low      0     0       0         0  20287     169    62.0
# 4         low  low      0     0       0         0  16202     166    67.0
#
#   gender pressure1 pressure2
# 0      f       100        80
# 1      m       120        82
# 2      m       120        80
# 3      m       120        80
# 4      m       120        80

# %% [markdown]
# ## Convertir variables categoricas a numericas
# Convertir variables categoricas a numericas utilizando la funcion

# %%
df = pd.get_dummies(df, columns=["cholesterol","gluc","gender"])

# %%
df.head()
# Out:
#    smoke  alco  active  diabetes    age  height  weight pressure1 pressure2  \
# 0      0     0       1         0  19710     169    76.0       100        80
# 1      0     0       1         0  17885     165    65.0       120        82
# 2      0     0       1         0  21962     170    56.0       120        80
# 3      0     0       0         0  20287     169    62.0       120        80
# 4      0     0       0         0  16202     166    67.0       120        80
#
#    cholesterol_high  cholesterol_low  cholesterol_medium  gluc_high  gluc_low  \
# 0                 0                1                   0          0         1
# 1                 0                1                   0          0         1
# 2                 0                1                   0          0         1
# 3                 0                1                   0          0         1
# 4                 0                1                   0          0         1
#
#    gluc_medium  gender_f  gender_m
# 0            0         1         0
# 1            0         0         1
# 2            0         0         1
# 3            0         0         1
# 4            0         0         1
