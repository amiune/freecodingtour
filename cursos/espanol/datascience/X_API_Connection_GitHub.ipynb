# %% [markdown]
# # API Connection

# %% [markdown]
# Connect to github
#
# - https://pygithub.readthedocs.io/en/stable/introduction.html
# - https://github.com/settings/tokens?type=beta
# - https://github.com/amiune/mldashboards

# %% [markdown]
# # La forma universal

# %%
import os
import base64
import datetime
import requests
from google.colab import userdata

# %%
github_token = userdata.get("GITHUB_DEMO_TOKEN")
repository = "amiune/mldashboards"

# %%
# https://docs.github.com/en/rest/repos/repos?apiVersion=2022-11-28#list-repositories-for-a-user
def list_github_repos():
    headers = {
        "Accept": "application/vnd.github+json",
        "X-GitHub-Api-Version": "2022-11-28"
    }
    ret = requests.get(
        f"https://api.github.com/users/amiune/repos",
        headers=headers,
    )
    repo_list = []
    for repo in ret.json():
      repo_list.append(repo["full_name"])

    return repo_list

list_github_repos()
# Out:
# ['amiune/amiune.github.io',
#  'amiune/CircleFinderChallenge',
#  'amiune/data2vec',
#  'amiune/fastapi-auth',
#  'amiune/Fellowship-challenges',
#  'amiune/freecodingtour',
#  'amiune/genai-stack',
#  'amiune/generativenetworks',
#  'amiune/jQuery-Windows-Engine-Plugin',
#  'amiune/mas.s62',
#  'amiune/mldashboards',
#  'amiune/MyTopCoderMMs',
#  'amiune/nano-blog',
#  'amiune/projecteuler',
#  'amiune/qiskit-terra',
#  'amiune/QiskitSummerSchool2020',
#  'amiune/QiskitSummerSchool2021',
#  'amiune/SeTeEscapoLaTortuga',
#  'amiune/Stanford-Cryptocurrencies-and-Blockchain-Technologies',
#  'amiune/streamlit-agent',
#  'amiune/streamlit-example',
#  'amiune/surphop',
#  'amiune/template']

# %%
# https://docs.github.com/en/rest/repos/repos?apiVersion=2022-11-28#list-repositories-for-a-user
def list_github_repos():
    headers = {
        "Accept": "application/vnd.github+json",
        "Authorization": f"Bearer {github_token}",
        "X-GitHub-Api-Version": "2022-11-28"
    }
    ret = requests.get(
        f"https://api.github.com/users/amiune/repos",
        headers=headers,
    )
    repo_list = []
    for repo in ret.json():
      repo_list.append(repo["full_name"])

    return repo_list

list_github_repos()

# %% [markdown]
# # Utilizando una libreria especifica para dicha API

# %%
# !pip install PyGithub -U -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.4/354.4 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 14.9 MB/s eta 0:00:00

# %%
from google.colab import userdata
from github import Github

# Authentication is defined via github.Auth
from github import Auth

# using an access token
auth = Auth.Token(userdata.get("GITHUB_DEMO_TOKEN"))

# Public Web Github
g = Github(auth=auth)

# %%
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# amiune.github.io
# CircleFinderChallenge
# data2vec
# fastapi-auth
# Fellowship-challenges
# freecodingtour
# genai-stack
# generativenetworks
# jQuery-Windows-Engine-Plugin
# mas.s62
# mldashboards
# MyTopCoderMMs
# nano-blog
# projecteuler
# qiskit-terra
# QiskitSummerSchool2020
# QiskitSummerSchool2021
# SeTeEscapoLaTortuga
# Stanford-Cryptocurrencies-and-Blockchain-Technologies
# streamlit-agent
# streamlit-example
# surphop
# template

# %%
repo = g.get_repo("amiune/mldashboards")
repo.stargazers_count
# Out:
# 0

# %%
repo = g.get_repo("amiune/mldashboards")
repo.create_file("README2.md", "create readme", "readme file added", branch="main")
# Out:
# {'content': ContentFile(path="README2.md"),
#  'commit': Commit(sha="050c27080cf29ec7999dfdbe02b6557175eb8688")}

# %%
repo = g.get_repo("amiune/mldashboards")
contents = repo.get_contents("README.md")
repo.update_file(contents.path, "modified readme", "# Hello World!", contents.sha, branch="main")
# Out:
# {'commit': Commit(sha="426903d475eb7aa7d0251b05f940c98bfd0fe356"),
#  'content': ContentFile(path="README.md")}

# %%
g.close()
